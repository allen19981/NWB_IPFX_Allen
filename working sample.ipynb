# %%
# Load IPFX libraries

from ipfx.dataset.create import create_ephys_data_set
from ipfx.data_set_features import extract_data_set_features
from ipfx.utilities import drop_failed_sweeps

# Load pandas library too
import pandas as pd

# %%
from ipfx.data_access import get_archive_info
archive_url, file_manifest, experiment_metadata = get_archive_info(dataset="human")

experiment_metadata.head()
# Out:
#       project  cell_specimen_id      cell_specimen_name hemisphere structure  \
# 0  hIVSCC-MET         541549258  H16.03.007.01.01.05.07       left       MTG
# 1  hIVSCC-MET         541557114  H16.03.007.01.01.05.10       left       MTG
# 2  hIVSCC-MET         567754968     H17.06.003.11.07.04       left       MTG
# 3  hIVSCC-MET         569835804     H17.03.002.11.09.04      right       MTG
# 4  hIVSCC-MET         569860121     H17.03.002.11.11.05      right       MTG
#
#      donor_id  donor_name biological_sex     age           ethnicity  \
# 0  H16.03.007  H16.03.007              F  28 yrs  White or Caucasian
# 1  H16.03.007  H16.03.007              F  28 yrs  White or Caucasian
# 2  H17.06.003  H17.06.003              F  23 yrs                 NaN
# 3  H17.03.002  H17.03.002              M  61 yrs             unknown
# 4  H17.03.002  H17.03.002              M  61 yrs             unknown
#
#               ...              dendrite_type  apical_dendrite_status  \
# 0             ...                      spiny                  intact
# 1             ...                      spiny                  intact
# 2             ...                      spiny               truncated
# 3             ...                      spiny                  intact
# 4             ...                      spiny                  intact
#
#   neuron_reconstruction_type cell_soma_normalized_depth depth_from_pia_um  \
# 0                       full                   0.165169             558.0
# 1              dendrite-only                   0.167381             540.0
# 2                        NaN                        NaN             825.0
# 3              dendrite-only                   0.080999             240.0
# 4              dendrite-only                   0.166927             460.0
#
#    ephys_session_id   transcriptomics_sample_id  transcriptomics_batch  \
# 0         541549227  RS1SS-161025-01_E12-50_S63                285-813
# 1         541557101  RS1SS-161025-01_E12-50_S66                285-813
# 2         567754895       huPSX170327_E1-50_S04                  BT024
# 3         569835791       huPSX170327_E1-50_S15                  BT024
# 4         569860104       huPSX170327_E1-50_S22                  BT024
#
#   corresponding_AIT2.3.1_ID corresponding_AIT2.3.1_alias
# 0                       NaN     Exc L2-3 LINC00507 FREM3
# 1                       NaN             Exc L2 LAMP5 LTK
# 2                       NaN     Exc L2-3 LINC00507 FREM3
# 3                       NaN             Exc L2 LAMP5 LTK
# 4                       NaN             Exc L2 LAMP5 LTK
#
# [5 rows x 22 columns]

# %%
import urllib.request

row = file_manifest.query('cell_specimen_id == 720856118 & technique == "intracellular_electrophysiology"')
archive_uri = row['archive_uri'].values[0]
file_name = row['file_name'].values[0]
print('Intrinsic ephys file url: ' + archive_uri)
print('Intrinsic ephys file name: ' + file_name)

print('downloading data for cell from DANDI...')
urllib.request.urlretrieve(archive_uri, file_name)
print('data downloaded!')
# Out:
# Intrinsic ephys file url: https://girder.dandiarchive.org/api/v1/item/5edab0df2dace54b6f9b2b1e/download
# Intrinsic ephys file name: sub-720619787_ses-720856105_icephys.nwb
# downloading data for cell from DANDI...
# data downloaded!

# %%
from ipfx.dataset.create import create_ephys_data_set
from ipfx.utilities import drop_failed_sweeps

# Create Ephys Data Set

print('loading dataset into data structure...')
#nwb_file_name = '/Users/stripathy/Downloads/sub-601462951_ses-601810292_icephys.nwb'
data_set = create_ephys_data_set(nwb_file=file_name) ##loads nwb file into ipfx data structure

# Drop failed sweeps: sweeps with incomplete recording or failing QC criteria
drop_failed_sweeps(data_set)
# Out:
# loading dataset into data structure...
# WARNING:root:sweep 56: ['Recording stopped before completing the experiment epoch']
# WARNING:root:sweep 57: ['Recording stopped before completing the experiment epoch']
# WARNING:root:sweep 58: ['Recording stopped before completing the experiment epoch']
# WARNING:root:sweep 59: ['Recording stopped before completing the experiment epoch']
# WARNING:root:sweep 60: ['Recording stopped before completing the experiment epoch']

# %%
from ipfx.data_set_features import extract_data_set_features

# Calculate ephys features
cell_features, sweep_features, cell_record, sweep_records, _, _ = extract_data_set_features(data_set)

# print cell_record
sweep_records
# Out:
# C:\Users\Allose\Anaconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# WARNING:root:Given time (1.500000) is outside of time range (-0.520000, 1.238740)
# C:\Users\Allose\Anaconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# C:\Users\Allose\Anaconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# [{'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': nan,
#   'passed': True,
#   'post_noise_rms_mv': 0.034420132637023926,
#   'post_vm_mv': -69.49091339111328,
#   'pre_noise_rms_mv': 0.044826630502939224,
#   'pre_vm_mv': -69.09245300292969,
#   'slow_noise_rms_mv': 0.2896440327167511,
#   'slow_vm_mv': -69.09245300292969,
#   'stimulus_amplitude': -110.0,
#   'stimulus_code': 'subthreshold_171',
#   'stimulus_code_ext': 'subthreshold_171[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 4,
#   'vm_delta_mv': 0.39846038818359375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 3.9823009967803955,
#   'passed': True,
#   'post_noise_rms_mv': 0.03806597366929054,
#   'post_vm_mv': -69.94827270507812,
#   'pre_noise_rms_mv': 0.0343751385807991,
#   'pre_vm_mv': -70.3785171508789,
#   'slow_noise_rms_mv': 0.11562477052211761,
#   'slow_vm_mv': -70.3785171508789,
#   'stimulus_amplitude': -90.0,
#   'stimulus_code': 'subthreshold_171',
#   'stimulus_code_ext': 'subthreshold_171[1]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 5,
#   'vm_delta_mv': 0.43024444580078125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 7.838179588317871,
#   'passed': True,
#   'post_noise_rms_mv': 0.03359178826212883,
#   'post_vm_mv': -70.00088500976562,
#   'pre_noise_rms_mv': 0.035828761756420135,
#   'pre_vm_mv': -69.75653839111328,
#   'slow_noise_rms_mv': 0.1486072689294815,
#   'slow_vm_mv': -69.75653839111328,
#   'stimulus_amplitude': -70.0,
#   'stimulus_code': 'subthreshold_171',
#   'stimulus_code_ext': 'subthreshold_171[2]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 6,
#   'vm_delta_mv': 0.24434661865234375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 7.838179588317871,
#   'passed': True,
#   'post_noise_rms_mv': 0.04144914075732231,
#   'post_vm_mv': -70.059326171875,
#   'pre_noise_rms_mv': 0.030946994200348854,
#   'pre_vm_mv': -70.0215072631836,
#   'slow_noise_rms_mv': 0.185529425740242,
#   'slow_vm_mv': -70.0215072631836,
#   'stimulus_amplitude': -50.0,
#   'stimulus_code': 'subthreshold_171',
#   'stimulus_code_ext': 'subthreshold_171[3]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 7,
#   'vm_delta_mv': 0.03781890869140625,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 7.838179588317871,
#   'passed': True,
#   'post_noise_rms_mv': 0.032264452427625656,
#   'post_vm_mv': -70.63694763183594,
#   'pre_noise_rms_mv': 0.032551731914281845,
#   'pre_vm_mv': -70.27594757080078,
#   'slow_noise_rms_mv': 0.17983804643154144,
#   'slow_vm_mv': -70.27594757080078,
#   'stimulus_amplitude': -29.999998092651367,
#   'stimulus_code': 'subthreshold_171',
#   'stimulus_code_ext': 'subthreshold_171[4]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 8,
#   'vm_delta_mv': 0.36100006103515625,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 14.917825698852539,
#   'passed': True,
#   'post_noise_rms_mv': 0.029622822999954224,
#   'post_vm_mv': -70.29556274414062,
#   'pre_noise_rms_mv': 0.033592235296964645,
#   'pre_vm_mv': -69.87555694580078,
#   'slow_noise_rms_mv': 0.19902469217777252,
#   'slow_vm_mv': -69.87555694580078,
#   'stimulus_amplitude': 100.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 10,
#   'vm_delta_mv': 0.42000579833984375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 14.917825698852539,
#   'passed': False,
#   'post_noise_rms_mv': 0.04591935873031616,
#   'post_vm_mv': -69.03640747070312,
#   'pre_noise_rms_mv': 0.03239394351840019,
#   'pre_vm_mv': -68.61360931396484,
#   'slow_noise_rms_mv': 0.5002221465110779,
#   'slow_vm_mv': -68.61360931396484,
#   'stimulus_amplitude': 110.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 11,
#   'vm_delta_mv': 0.42279815673828125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 14.917825698852539,
#   'passed': True,
#   'post_noise_rms_mv': 0.03654851019382477,
#   'post_vm_mv': -70.42044830322266,
#   'pre_noise_rms_mv': 0.04239073023200035,
#   'pre_vm_mv': -70.03980255126953,
#   'slow_noise_rms_mv': 0.14120836555957794,
#   'slow_vm_mv': -70.03980255126953,
#   'stimulus_amplitude': 119.99999237060547,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 12,
#   'vm_delta_mv': 0.380645751953125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 18.584070205688477,
#   'passed': True,
#   'post_noise_rms_mv': 0.036204878240823746,
#   'post_vm_mv': -70.15662384033203,
#   'pre_noise_rms_mv': 0.03963812068104744,
#   'pre_vm_mv': -69.55459594726562,
#   'slow_noise_rms_mv': 0.15657003223896027,
#   'slow_vm_mv': -69.55459594726562,
#   'stimulus_amplitude': 130.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 13,
#   'vm_delta_mv': 0.6020278930664062,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 21.99747085571289,
#   'passed': True,
#   'post_noise_rms_mv': 0.03568204864859581,
#   'post_vm_mv': -69.94326782226562,
#   'pre_noise_rms_mv': 0.04622216150164604,
#   'pre_vm_mv': -69.84542083740234,
#   'slow_noise_rms_mv': 0.09403091669082642,
#   'slow_vm_mv': -69.84542083740234,
#   'stimulus_amplitude': 140.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 14,
#   'vm_delta_mv': 0.09784698486328125,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 24.905183792114258,
#   'passed': True,
#   'post_noise_rms_mv': 0.03368712589144707,
#   'post_vm_mv': -69.68771362304688,
#   'pre_noise_rms_mv': 0.028706517070531845,
#   'pre_vm_mv': -69.45740509033203,
#   'slow_noise_rms_mv': 0.11658782511949539,
#   'slow_vm_mv': -69.45740509033203,
#   'stimulus_amplitude': 180.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 15,
#   'vm_delta_mv': 0.23030853271484375,
#   'peak_deflection': None,
#   'num_spikes': 2},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 24.905183792114258,
#   'passed': False,
#   'post_noise_rms_mv': 0.04738929495215416,
#   'post_vm_mv': -68.30827331542969,
#   'pre_noise_rms_mv': 0.03240947797894478,
#   'pre_vm_mv': -69.64292907714844,
#   'slow_noise_rms_mv': 0.08912889659404755,
#   'slow_vm_mv': -69.64292907714844,
#   'stimulus_amplitude': 220.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 16,
#   'vm_delta_mv': 1.33465576171875,
#   'peak_deflection': None,
#   'num_spikes': 5},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 24.905183792114258,
#   'passed': False,
#   'post_noise_rms_mv': 0.07727969437837601,
#   'post_vm_mv': -40.78728485107422,
#   'pre_noise_rms_mv': 0.03725422918796539,
#   'pre_vm_mv': -68.58676147460938,
#   'slow_noise_rms_mv': 0.3382847309112549,
#   'slow_vm_mv': -68.58676147460938,
#   'stimulus_amplitude': 0.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': nan,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': nan,
#   'stimulus_units': 'Amps',
#   'sweep_number': 17,
#   'vm_delta_mv': 27.799476623535156,
#   'peak_deflection': None,
#   'num_spikes': 11},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 24.905183792114258,
#   'passed': True,
#   'post_noise_rms_mv': 0.035707131028175354,
#   'post_vm_mv': -68.69745635986328,
#   'pre_noise_rms_mv': 0.04380855709314346,
#   'pre_vm_mv': -68.78014373779297,
#   'slow_noise_rms_mv': 0.25745877623558044,
#   'slow_vm_mv': -68.78014373779297,
#   'stimulus_amplitude': 300.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 18,
#   'vm_delta_mv': 0.0826873779296875,
#   'peak_deflection': None,
#   'num_spikes': 13},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 21.554994583129883,
#   'passed': True,
#   'post_noise_rms_mv': 0.0389750711619854,
#   'post_vm_mv': -68.52134704589844,
#   'pre_noise_rms_mv': 0.04659132659435272,
#   'pre_vm_mv': -68.51277923583984,
#   'slow_noise_rms_mv': 0.2857879400253296,
#   'slow_vm_mv': -68.51277923583984,
#   'stimulus_amplitude': 999.9999389648438,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 20,
#   'vm_delta_mv': 0.00856781005859375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 21.554994583129883,
#   'passed': True,
#   'post_noise_rms_mv': 0.03690456226468086,
#   'post_vm_mv': -68.74745178222656,
#   'pre_noise_rms_mv': 0.04602157324552536,
#   'pre_vm_mv': -68.8653564453125,
#   'slow_noise_rms_mv': 0.15033765137195587,
#   'slow_vm_mv': -68.8653564453125,
#   'stimulus_amplitude': 1100.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 21,
#   'vm_delta_mv': 0.1179046630859375,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 21.554994583129883,
#   'passed': True,
#   'post_noise_rms_mv': 0.03190899267792702,
#   'post_vm_mv': -69.03801727294922,
#   'pre_noise_rms_mv': 0.039963651448488235,
#   'pre_vm_mv': -69.02593231201172,
#   'slow_noise_rms_mv': 0.2212754338979721,
#   'slow_vm_mv': -69.02593231201172,
#   'stimulus_amplitude': 1050.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 22,
#   'vm_delta_mv': 0.0120849609375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 21.554994583129883,
#   'passed': False,
#   'post_noise_rms_mv': 0.04187549650669098,
#   'post_vm_mv': -66.54733276367188,
#   'pre_noise_rms_mv': 0.03544572740793228,
#   'pre_vm_mv': -68.87387084960938,
#   'slow_noise_rms_mv': 0.7340171933174133,
#   'slow_vm_mv': -68.87387084960938,
#   'stimulus_amplitude': 1070.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 23,
#   'vm_delta_mv': 2.3265380859375,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -3.9190897941589355,
#   'passed': True,
#   'post_noise_rms_mv': 0.03434473276138306,
#   'post_vm_mv': -66.93864440917969,
#   'pre_noise_rms_mv': 0.03618985414505005,
#   'pre_vm_mv': -67.01436614990234,
#   'slow_noise_rms_mv': 0.12554983794689178,
#   'slow_vm_mv': -67.01436614990234,
#   'stimulus_amplitude': 1060.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 24,
#   'vm_delta_mv': 0.07572174072265625,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.423515319824219,
#   'passed': True,
#   'post_noise_rms_mv': 0.02630767412483692,
#   'post_vm_mv': -67.91790771484375,
#   'pre_noise_rms_mv': 0.03394254669547081,
#   'pre_vm_mv': -68.06935119628906,
#   'slow_noise_rms_mv': 0.14268608391284943,
#   'slow_vm_mv': -68.06935119628906,
#   'stimulus_amplitude': 1070.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 25,
#   'vm_delta_mv': 0.1514434814453125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.423515319824219,
#   'passed': True,
#   'post_noise_rms_mv': 0.03496870771050453,
#   'post_vm_mv': -68.0037612915039,
#   'pre_noise_rms_mv': 0.037740256637334824,
#   'pre_vm_mv': -68.00504302978516,
#   'slow_noise_rms_mv': 0.14544184505939484,
#   'slow_vm_mv': -68.00504302978516,
#   'stimulus_amplitude': 1080.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 26,
#   'vm_delta_mv': 0.00128173828125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.423515319824219,
#   'passed': True,
#   'post_noise_rms_mv': 0.03898905590176582,
#   'post_vm_mv': -68.52692413330078,
#   'pre_noise_rms_mv': 0.03704574704170227,
#   'pre_vm_mv': -68.58512115478516,
#   'slow_noise_rms_mv': 0.14278915524482727,
#   'slow_vm_mv': -68.58512115478516,
#   'stimulus_amplitude': 1090.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 27,
#   'vm_delta_mv': 0.058197021484375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.423515319824219,
#   'passed': True,
#   'post_noise_rms_mv': 0.03531799092888832,
#   'post_vm_mv': -68.86475372314453,
#   'pre_noise_rms_mv': 0.042869023978710175,
#   'pre_vm_mv': -68.89494323730469,
#   'slow_noise_rms_mv': 0.23985762894153595,
#   'slow_vm_mv': -68.89494323730469,
#   'stimulus_amplitude': 1100.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 28,
#   'vm_delta_mv': 0.03018951416015625,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.423515319824219,
#   'passed': True,
#   'post_noise_rms_mv': 0.03885554149746895,
#   'post_vm_mv': -69.48770904541016,
#   'pre_noise_rms_mv': 0.027992557734251022,
#   'pre_vm_mv': -69.36827850341797,
#   'slow_noise_rms_mv': 0.1377493292093277,
#   'slow_vm_mv': -69.36827850341797,
#   'stimulus_amplitude': 1110.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 29,
#   'vm_delta_mv': 0.1194305419921875,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.423515319824219,
#   'passed': True,
#   'post_noise_rms_mv': 0.03201498091220856,
#   'post_vm_mv': -69.52789306640625,
#   'pre_noise_rms_mv': 0.03346353396773338,
#   'pre_vm_mv': -69.3547592163086,
#   'slow_noise_rms_mv': 0.11931227147579193,
#   'slow_vm_mv': -69.3547592163086,
#   'stimulus_amplitude': 1120.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 30,
#   'vm_delta_mv': 0.17313385009765625,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.423515319824219,
#   'passed': True,
#   'post_noise_rms_mv': 0.032851241528987885,
#   'post_vm_mv': -70.03865814208984,
#   'pre_noise_rms_mv': 0.03655979037284851,
#   'pre_vm_mv': -69.74341583251953,
#   'slow_noise_rms_mv': 0.1406978964805603,
#   'slow_vm_mv': -69.74341583251953,
#   'stimulus_amplitude': 1130.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 31,
#   'vm_delta_mv': 0.2952423095703125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -12.13653564453125,
#   'passed': True,
#   'post_noise_rms_mv': 0.03808463737368584,
#   'post_vm_mv': -70.13169860839844,
#   'pre_noise_rms_mv': 0.03566480427980423,
#   'pre_vm_mv': -69.80403137207031,
#   'slow_noise_rms_mv': 0.16602420806884766,
#   'slow_vm_mv': -69.80403137207031,
#   'stimulus_amplitude': 1140.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 32,
#   'vm_delta_mv': 0.327667236328125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -12.13653564453125,
#   'passed': True,
#   'post_noise_rms_mv': 0.03033388964831829,
#   'post_vm_mv': -69.57160949707031,
#   'pre_noise_rms_mv': 0.03921079263091087,
#   'pre_vm_mv': -69.330078125,
#   'slow_noise_rms_mv': 0.16822050511837006,
#   'slow_vm_mv': -69.330078125,
#   'stimulus_amplitude': 1150.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 33,
#   'vm_delta_mv': 0.2415313720703125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -12.13653564453125,
#   'passed': True,
#   'post_noise_rms_mv': 0.0486803762614727,
#   'post_vm_mv': -70.3955078125,
#   'pre_noise_rms_mv': 0.03676293417811394,
#   'pre_vm_mv': -70.46782684326172,
#   'slow_noise_rms_mv': 0.06753960996866226,
#   'slow_vm_mv': -70.46782684326172,
#   'stimulus_amplitude': 1160.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 34,
#   'vm_delta_mv': 0.07231903076171875,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -6.321112632751465,
#   'passed': True,
#   'post_noise_rms_mv': 0.03661983087658882,
#   'post_vm_mv': -69.2451400756836,
#   'pre_noise_rms_mv': 0.03452577441930771,
#   'pre_vm_mv': -69.37146759033203,
#   'slow_noise_rms_mv': 0.17590421438217163,
#   'slow_vm_mv': -69.37146759033203,
#   'stimulus_amplitude': 1170.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 35,
#   'vm_delta_mv': 0.1263275146484375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -6.321112632751465,
#   'passed': True,
#   'post_noise_rms_mv': 0.036289799958467484,
#   'post_vm_mv': -70.16285705566406,
#   'pre_noise_rms_mv': 0.03999944403767586,
#   'pre_vm_mv': -69.86726379394531,
#   'slow_noise_rms_mv': 0.15611232817173004,
#   'slow_vm_mv': -69.86726379394531,
#   'stimulus_amplitude': 1180.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 36,
#   'vm_delta_mv': 0.29559326171875,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -2.718078374862671,
#   'passed': True,
#   'post_noise_rms_mv': 0.027373870834708214,
#   'post_vm_mv': -69.33465576171875,
#   'pre_noise_rms_mv': 0.039934076368808746,
#   'pre_vm_mv': -69.12867736816406,
#   'slow_noise_rms_mv': 0.2088918834924698,
#   'slow_vm_mv': -69.12867736816406,
#   'stimulus_amplitude': 1190.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 37,
#   'vm_delta_mv': 0.2059783935546875,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -2.718078374862671,
#   'passed': True,
#   'post_noise_rms_mv': 0.037500202655792236,
#   'post_vm_mv': -69.21173858642578,
#   'pre_noise_rms_mv': 0.03519317880272865,
#   'pre_vm_mv': -69.67848205566406,
#   'slow_noise_rms_mv': 0.22851847112178802,
#   'slow_vm_mv': -69.67848205566406,
#   'stimulus_amplitude': 1200.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 38,
#   'vm_delta_mv': 0.46674346923828125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -2.718078374862671,
#   'passed': True,
#   'post_noise_rms_mv': 0.04050622880458832,
#   'post_vm_mv': -69.92597198486328,
#   'pre_noise_rms_mv': 0.03571319580078125,
#   'pre_vm_mv': -69.93611145019531,
#   'slow_noise_rms_mv': 0.256307989358902,
#   'slow_vm_mv': -69.93611145019531,
#   'stimulus_amplitude': 1250.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 39,
#   'vm_delta_mv': 0.01013946533203125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 1.264222502708435,
#   'passed': True,
#   'post_noise_rms_mv': 0.03444748371839523,
#   'post_vm_mv': -69.79398345947266,
#   'pre_noise_rms_mv': 0.04280603677034378,
#   'pre_vm_mv': -69.69873809814453,
#   'slow_noise_rms_mv': 0.2608046233654022,
#   'slow_vm_mv': -69.69873809814453,
#   'stimulus_amplitude': 1290.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 40,
#   'vm_delta_mv': 0.095245361328125,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 5.05689001083374,
#   'passed': True,
#   'post_noise_rms_mv': 0.037002354860305786,
#   'post_vm_mv': -69.42680358886719,
#   'pre_noise_rms_mv': 0.03626244515180588,
#   'pre_vm_mv': -69.55388641357422,
#   'slow_noise_rms_mv': 0.3235492706298828,
#   'slow_vm_mv': -69.55388641357422,
#   'stimulus_amplitude': 1270.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 41,
#   'vm_delta_mv': 0.12708282470703125,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 5.05689001083374,
#   'passed': False,
#   'post_noise_rms_mv': 0.04036688804626465,
#   'post_vm_mv': -65.49968719482422,
#   'pre_noise_rms_mv': 0.8476880788803101,
#   'pre_vm_mv': -66.70465087890625,
#   'slow_noise_rms_mv': 0.23235517740249634,
#   'slow_vm_mv': -66.70465087890625,
#   'stimulus_amplitude': 1260.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 42,
#   'vm_delta_mv': 1.2049636840820312,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -21.365360260009766,
#   'passed': True,
#   'post_noise_rms_mv': 0.03320420905947685,
#   'post_vm_mv': -69.18279266357422,
#   'pre_noise_rms_mv': 0.040288642048835754,
#   'pre_vm_mv': -69.30123138427734,
#   'slow_noise_rms_mv': 0.16586579382419586,
#   'slow_vm_mv': -69.30123138427734,
#   'stimulus_amplitude': 1270.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 43,
#   'vm_delta_mv': 0.118438720703125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -21.365360260009766,
#   'passed': True,
#   'post_noise_rms_mv': 0.037267494946718216,
#   'post_vm_mv': -69.56990051269531,
#   'pre_noise_rms_mv': 0.031742993742227554,
#   'pre_vm_mv': -69.28952026367188,
#   'slow_noise_rms_mv': 0.1341262310743332,
#   'slow_vm_mv': -69.28952026367188,
#   'stimulus_amplitude': 1280.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 44,
#   'vm_delta_mv': 0.2803802490234375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -21.365360260009766,
#   'passed': True,
#   'post_noise_rms_mv': 0.03796180337667465,
#   'post_vm_mv': -70.179443359375,
#   'pre_noise_rms_mv': 0.032906122505664825,
#   'pre_vm_mv': -69.76066589355469,
#   'slow_noise_rms_mv': 0.1625131368637085,
#   'slow_vm_mv': -69.76066589355469,
#   'stimulus_amplitude': 1290.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 45,
#   'vm_delta_mv': 0.4187774658203125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -16.561315536499023,
#   'passed': True,
#   'post_noise_rms_mv': 0.031163446605205536,
#   'post_vm_mv': -70.35981750488281,
#   'pre_noise_rms_mv': 0.03664284199476242,
#   'pre_vm_mv': -70.14241790771484,
#   'slow_noise_rms_mv': 0.1932222843170166,
#   'slow_vm_mv': -70.14241790771484,
#   'stimulus_amplitude': 1300.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 46,
#   'vm_delta_mv': 0.21739959716796875,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -12.958280563354492,
#   'passed': True,
#   'post_noise_rms_mv': 0.03718371316790581,
#   'post_vm_mv': -70.22081756591797,
#   'pre_noise_rms_mv': 0.03568318486213684,
#   'pre_vm_mv': -69.79826354980469,
#   'slow_noise_rms_mv': 0.12585970759391785,
#   'slow_vm_mv': -69.79826354980469,
#   'stimulus_amplitude': 1350.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 47,
#   'vm_delta_mv': 0.42255401611328125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -12.958280563354492,
#   'passed': True,
#   'post_noise_rms_mv': 0.03993508219718933,
#   'post_vm_mv': -70.53816986083984,
#   'pre_noise_rms_mv': 0.03787584230303764,
#   'pre_vm_mv': -70.37184143066406,
#   'slow_noise_rms_mv': 0.149828240275383,
#   'slow_vm_mv': -70.37184143066406,
#   'stimulus_amplitude': 1390.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 48,
#   'vm_delta_mv': 0.16632843017578125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -3.7294564247131348,
#   'passed': True,
#   'post_noise_rms_mv': 0.036917101591825485,
#   'post_vm_mv': -69.85185241699219,
#   'pre_noise_rms_mv': 0.02924620360136032,
#   'pre_vm_mv': -69.6297378540039,
#   'slow_noise_rms_mv': 0.16847465932369232,
#   'slow_vm_mv': -69.6297378540039,
#   'stimulus_amplitude': 1400.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 49,
#   'vm_delta_mv': 0.22211456298828125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -0.37926673889160156,
#   'passed': True,
#   'post_noise_rms_mv': 0.034570131450891495,
#   'post_vm_mv': -69.9772720336914,
#   'pre_noise_rms_mv': 0.0310231763869524,
#   'pre_vm_mv': -69.9064712524414,
#   'slow_noise_rms_mv': 0.1142650619149208,
#   'slow_vm_mv': -69.9064712524414,
#   'stimulus_amplitude': 1450.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 50,
#   'vm_delta_mv': 0.07080078125,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 3.413400888442993,
#   'passed': True,
#   'post_noise_rms_mv': 0.03692625090479851,
#   'post_vm_mv': -69.62238311767578,
#   'pre_noise_rms_mv': 0.03457264602184296,
#   'pre_vm_mv': -69.64620971679688,
#   'slow_noise_rms_mv': 0.1482699066400528,
#   'slow_vm_mv': -69.64620971679688,
#   'stimulus_amplitude': 1410.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 51,
#   'vm_delta_mv': 0.02382659912109375,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 3.413400888442993,
#   'passed': True,
#   'post_noise_rms_mv': 0.041363347321748734,
#   'post_vm_mv': -69.83756256103516,
#   'pre_noise_rms_mv': 0.030944567173719406,
#   'pre_vm_mv': -69.9089126586914,
#   'slow_noise_rms_mv': 0.10520985722541809,
#   'slow_vm_mv': -69.9089126586914,
#   'stimulus_amplitude': 1410.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 52,
#   'vm_delta_mv': 0.07135009765625,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 6.826801776885986,
#   'passed': False,
#   'post_noise_rms_mv': 0.03509635478258133,
#   'post_vm_mv': -69.1615982055664,
#   'pre_noise_rms_mv': 0.040182434022426605,
#   'pre_vm_mv': -68.66974639892578,
#   'slow_noise_rms_mv': 0.8343677520751953,
#   'slow_vm_mv': -68.66974639892578,
#   'stimulus_amplitude': 1410.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 53,
#   'vm_delta_mv': 0.491851806640625,
#   'peak_deflection': None,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 4.361567497253418,
#   'passed': True,
#   'post_noise_rms_mv': nan,
#   'post_vm_mv': nan,
#   'pre_noise_rms_mv': 0.031247930601239204,
#   'pre_vm_mv': -70.06220245361328,
#   'slow_noise_rms_mv': 0.1932087391614914,
#   'slow_vm_mv': -70.06220245361328,
#   'stimulus_amplitude': 315.875,
#   'stimulus_code': 'C1RP25PR1S141203',
#   'stimulus_code_ext': 'C1RP25PR1S141203[0]',
#   'stimulus_duration': 12.635,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Ramp',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.0225,
#   'stimulus_units': 'Amps',
#   'sweep_number': 54,
#   'vm_delta_mv': nan,
#   'peak_deflection': None,
#   'num_spikes': 7},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 11.378003120422363,
#   'passed': True,
#   'post_noise_rms_mv': nan,
#   'post_vm_mv': nan,
#   'pre_noise_rms_mv': 0.03773951530456543,
#   'pre_vm_mv': -70.08612823486328,
#   'slow_noise_rms_mv': 0.13125257194042206,
#   'slow_vm_mv': -70.08612823486328,
#   'stimulus_amplitude': 346.875,
#   'stimulus_code': 'C1RP25PR1S141203',
#   'stimulus_code_ext': 'C1RP25PR1S141203[0]',
#   'stimulus_duration': 13.875,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Ramp',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.0225,
#   'stimulus_units': 'Amps',
#   'sweep_number': 55,
#   'vm_delta_mv': nan,
#   'peak_deflection': None,
#   'num_spikes': 12},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -0.5056890249252319,
#   'passed': False,
#   'post_noise_rms_mv': 0.03094477765262127,
#   'post_vm_mv': -68.38655090332031,
#   'pre_noise_rms_mv': 0.04369939863681793,
#   'pre_vm_mv': -69.49601745605469,
#   'slow_noise_rms_mv': 0.26715004444122314,
#   'slow_vm_mv': -69.49601745605469,
#   'stimulus_amplitude': -48.0,
#   'stimulus_code': 'C2CHIRP180503',
#   'stimulus_code_ext': 'C2CHIRP180503[0]',
#   'stimulus_duration': 19.999480000000002,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Unknown',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.52052,
#   'stimulus_units': 'Amps',
#   'sweep_number': 61,
#   'vm_delta_mv': 1.109466552734375,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -0.5056890249252319,
#   'passed': True,
#   'post_noise_rms_mv': 0.03706663101911545,
#   'post_vm_mv': -67.87454986572266,
#   'pre_noise_rms_mv': 0.05467178672552109,
#   'pre_vm_mv': -68.32695770263672,
#   'slow_noise_rms_mv': 0.2629459500312805,
#   'slow_vm_mv': -68.32695770263672,
#   'stimulus_amplitude': -48.0,
#   'stimulus_code': 'C2CHIRP180503',
#   'stimulus_code_ext': 'C2CHIRP180503[0]',
#   'stimulus_duration': 19.999480000000002,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Unknown',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.52052,
#   'stimulus_units': 'Amps',
#   'sweep_number': 62,
#   'vm_delta_mv': 0.4524078369140625,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -0.5056890249252319,
#   'passed': True,
#   'post_noise_rms_mv': 0.030573729425668716,
#   'post_vm_mv': -67.7453384399414,
#   'pre_noise_rms_mv': 0.0444558821618557,
#   'pre_vm_mv': -67.56314086914062,
#   'slow_noise_rms_mv': 0.30620843172073364,
#   'slow_vm_mv': -67.56314086914062,
#   'stimulus_amplitude': -48.0,
#   'stimulus_code': 'C2CHIRP180503',
#   'stimulus_code_ext': 'C2CHIRP180503[0]',
#   'stimulus_duration': 19.999480000000002,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Unknown',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.52052,
#   'stimulus_units': 'Amps',
#   'sweep_number': 63,
#   'vm_delta_mv': 0.18219757080078125,
#   'peak_deflection': None,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -6.194690227508545,
#   'passed': True,
#   'post_noise_rms_mv': 0.03388511762022972,
#   'post_vm_mv': -68.09142303466797,
#   'pre_noise_rms_mv': 0.05574720352888107,
#   'pre_vm_mv': -68.0345230102539,
#   'slow_noise_rms_mv': 0.19557848572731018,
#   'slow_vm_mv': -68.0345230102539,
#   'stimulus_amplitude': 324.5,
#   'stimulus_code': 'C1NSD1SHORT17110',
#   'stimulus_code_ext': 'C1NSD1SHORT17110[0]',
#   'stimulus_duration': 10.0,
#   'stimulus_interval': 3.5,
#   'stimulus_name': 'Noise 1',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.52,
#   'stimulus_units': 'Amps',
#   'sweep_number': 64,
#   'vm_delta_mv': 0.0569000244140625,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -6.194690227508545,
#   'passed': False,
#   'post_noise_rms_mv': 0.04004373028874397,
#   'post_vm_mv': -68.65538787841797,
#   'pre_noise_rms_mv': 0.04630376771092415,
#   'pre_vm_mv': -67.58474731445312,
#   'slow_noise_rms_mv': 0.25040918588638306,
#   'slow_vm_mv': -67.58474731445312,
#   'stimulus_amplitude': 330.125,
#   'stimulus_code': 'C1NSD2SHORT17110',
#   'stimulus_code_ext': 'C1NSD2SHORT17110[0]',
#   'stimulus_duration': 10.0,
#   'stimulus_interval': 3.5,
#   'stimulus_name': 'Noise 2',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.52,
#   'stimulus_units': 'Amps',
#   'sweep_number': 65,
#   'vm_delta_mv': 1.0706405639648438,
#   'peak_deflection': None,
#   'num_spikes': 5},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -6.194690227508545,
#   'passed': False,
#   'post_noise_rms_mv': 0.034673821181058884,
#   'post_vm_mv': -81.76141357421875,
#   'pre_noise_rms_mv': 0.04918552562594414,
#   'pre_vm_mv': -68.47756958007812,
#   'slow_noise_rms_mv': 0.2606506943702698,
#   'slow_vm_mv': -68.47756958007812,
#   'stimulus_amplitude': 324.5,
#   'stimulus_code': 'C1NSD1SHORT17110',
#   'stimulus_code_ext': 'C1NSD1SHORT17110[0]',
#   'stimulus_duration': 10.0,
#   'stimulus_interval': 3.5,
#   'stimulus_name': 'Noise 1',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.52,
#   'stimulus_units': 'Amps',
#   'sweep_number': 66,
#   'vm_delta_mv': 13.283843994140625,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -6.194690227508545,
#   'passed': True,
#   'post_noise_rms_mv': 0.043825358152389526,
#   'post_vm_mv': -81.50232696533203,
#   'pre_noise_rms_mv': 0.0659453496336937,
#   'pre_vm_mv': -81.03118133544922,
#   'slow_noise_rms_mv': 0.43280935287475586,
#   'slow_vm_mv': -81.03118133544922,
#   'stimulus_amplitude': 330.125,
#   'stimulus_code': 'C1NSD2SHORT17110',
#   'stimulus_code_ext': 'C1NSD2SHORT17110[0]',
#   'stimulus_duration': 10.0,
#   'stimulus_interval': 3.5,
#   'stimulus_name': 'Noise 2',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.52,
#   'stimulus_units': 'Amps',
#   'sweep_number': 67,
#   'vm_delta_mv': 0.4711456298828125,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -14.096080780029297,
#   'passed': False,
#   'post_noise_rms_mv': 0.03620360419154167,
#   'post_vm_mv': -69.659912109375,
#   'pre_noise_rms_mv': 0.037765923887491226,
#   'pre_vm_mv': -69.43851470947266,
#   'slow_noise_rms_mv': 0.527290940284729,
#   'slow_vm_mv': -69.43851470947266,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[0]',
#   'stimulus_duration': 0.04302,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 68,
#   'vm_delta_mv': 0.22139739990234375,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -9.608091354370117,
#   'passed': False,
#   'post_noise_rms_mv': 0.037254415452480316,
#   'post_vm_mv': -70.23812866210938,
#   'pre_noise_rms_mv': 0.041142381727695465,
#   'pre_vm_mv': -69.80917358398438,
#   'slow_noise_rms_mv': 0.5240373015403748,
#   'slow_vm_mv': -69.80917358398438,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[1]',
#   'stimulus_duration': 0.03633999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 69,
#   'vm_delta_mv': 0.428955078125,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -7.648545742034912,
#   'passed': True,
#   'post_noise_rms_mv': 0.0353449247777462,
#   'post_vm_mv': -61.21517562866211,
#   'pre_noise_rms_mv': 0.03795962408185005,
#   'pre_vm_mv': -62.05223083496094,
#   'slow_noise_rms_mv': 0.40718841552734375,
#   'slow_vm_mv': -62.05223083496094,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[2]',
#   'stimulus_duration': 0.03158,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
# ...
#   'stimulus_units': 'Amps',
#   'sweep_number': 80,
#   'vm_delta_mv': 0.332000732421875,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -33.12263107299805,
#   'passed': False,
#   'post_noise_rms_mv': 0.03929400444030762,
#   'post_vm_mv': -69.8322525024414,
#   'pre_noise_rms_mv': 0.037026338279247284,
#   'pre_vm_mv': -69.71690368652344,
#   'slow_noise_rms_mv': 0.5567223429679871,
#   'slow_vm_mv': -69.71690368652344,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[2]',
#   'stimulus_duration': 0.03158,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 81,
#   'vm_delta_mv': 0.11534881591796875,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -29.3299617767334,
#   'passed': True,
#   'post_noise_rms_mv': 0.03751605376601219,
#   'post_vm_mv': -69.7580337524414,
#   'pre_noise_rms_mv': 0.036833904683589935,
#   'pre_vm_mv': -69.47007751464844,
#   'slow_noise_rms_mv': 0.4662854075431824,
#   'slow_vm_mv': -69.47007751464844,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[3]',
#   'stimulus_duration': 0.02801999999999999,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 82,
#   'vm_delta_mv': 0.28795623779296875,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -29.3299617767334,
#   'passed': True,
#   'post_noise_rms_mv': 0.034342627972364426,
#   'post_vm_mv': -70.0191421508789,
#   'pre_noise_rms_mv': 0.02988353744149208,
#   'pre_vm_mv': -69.83319091796875,
#   'slow_noise_rms_mv': 0.43108615279197693,
#   'slow_vm_mv': -69.83319091796875,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[4]',
#   'stimulus_duration': 0.025239999999999985,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 83,
#   'vm_delta_mv': 0.18595123291015625,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -19.78508186340332,
#   'passed': False,
#   'post_noise_rms_mv': 0.026518017053604126,
#   'post_vm_mv': -69.71820831298828,
#   'pre_noise_rms_mv': 0.03614615648984909,
#   'pre_vm_mv': -69.32344818115234,
#   'slow_noise_rms_mv': 0.5196644067764282,
#   'slow_vm_mv': -69.32344818115234,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[5]',
#   'stimulus_duration': 0.023019999999999985,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 84,
#   'vm_delta_mv': 0.3947601318359375,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.929203987121582,
#   'passed': False,
#   'post_noise_rms_mv': 0.035843465477228165,
#   'post_vm_mv': -69.66143035888672,
#   'pre_noise_rms_mv': 0.03656264394521713,
#   'pre_vm_mv': -69.48201751708984,
#   'slow_noise_rms_mv': 0.5116057991981506,
#   'slow_vm_mv': -69.48201751708984,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[6]',
#   'stimulus_duration': 0.021199999999999997,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 85,
#   'vm_delta_mv': 0.179412841796875,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -15.929203987121582,
#   'passed': False,
#   'post_noise_rms_mv': 0.03640484809875488,
#   'post_vm_mv': -70.04486083984375,
#   'pre_noise_rms_mv': 0.03161076456308365,
#   'pre_vm_mv': -69.65098571777344,
#   'slow_noise_rms_mv': 0.574280858039856,
#   'slow_vm_mv': -69.65098571777344,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[7]',
#   'stimulus_duration': 0.019680000000000003,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 86,
#   'vm_delta_mv': 0.3938751220703125,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -11.883691787719727,
#   'passed': True,
#   'post_noise_rms_mv': 0.04441847279667854,
#   'post_vm_mv': -69.21815490722656,
#   'pre_noise_rms_mv': 0.03406751900911331,
#   'pre_vm_mv': -69.67279052734375,
#   'slow_noise_rms_mv': 0.4167121946811676,
#   'slow_vm_mv': -69.67279052734375,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[8]',
#   'stimulus_duration': 0.0184,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 87,
#   'vm_delta_mv': 0.4546356201171875,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -7.20606803894043,
#   'passed': False,
#   'post_noise_rms_mv': 0.04323166608810425,
#   'post_vm_mv': -69.7484130859375,
#   'pre_noise_rms_mv': 0.030742790549993515,
#   'pre_vm_mv': -69.3119125366211,
#   'slow_noise_rms_mv': 0.5511990189552307,
#   'slow_vm_mv': -69.3119125366211,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[9]',
#   'stimulus_duration': 0.017299999999999982,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 88,
#   'vm_delta_mv': 0.43650054931640625,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -7.20606803894043,
#   'passed': True,
#   'post_noise_rms_mv': 0.04416459798812866,
#   'post_vm_mv': -69.64221954345703,
#   'pre_noise_rms_mv': 0.029564518481492996,
#   'pre_vm_mv': -69.41473388671875,
#   'slow_noise_rms_mv': 0.43184906244277954,
#   'slow_vm_mv': -69.41473388671875,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[10]',
#   'stimulus_duration': 0.016339999999999993,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 89,
#   'vm_delta_mv': 0.22748565673828125,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': -3.2869784832000732,
#   'passed': False,
#   'post_noise_rms_mv': 0.03218358755111694,
#   'post_vm_mv': -69.85328674316406,
#   'pre_noise_rms_mv': 0.03931562229990959,
#   'pre_vm_mv': -69.44274139404297,
#   'slow_noise_rms_mv': 0.5610595941543579,
#   'slow_vm_mv': -69.44274139404297,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[0]',
#   'stimulus_duration': 0.04302,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 90,
#   'vm_delta_mv': 0.41054534912109375,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 1.4538558721542358,
#   'passed': False,
#   'post_noise_rms_mv': 0.030858805403113365,
#   'post_vm_mv': -69.53617858886719,
#   'pre_noise_rms_mv': 0.029569748789072037,
#   'pre_vm_mv': -69.50923156738281,
#   'slow_noise_rms_mv': 0.5655268430709839,
#   'slow_vm_mv': -69.50923156738281,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[1]',
#   'stimulus_duration': 0.03633999999999998,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 91,
#   'vm_delta_mv': 0.026947021484375,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 1.4538558721542358,
#   'passed': True,
#   'post_noise_rms_mv': 0.03679727762937546,
#   'post_vm_mv': -69.52718353271484,
#   'pre_noise_rms_mv': 0.02875710278749466,
#   'pre_vm_mv': -69.69902038574219,
#   'slow_noise_rms_mv': 0.4896281361579895,
#   'slow_vm_mv': -69.69902038574219,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[2]',
#   'stimulus_duration': 0.03158,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 92,
#   'vm_delta_mv': 0.17183685302734375,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 1.4538558721542358,
#   'passed': False,
#   'post_noise_rms_mv': 0.02441568672657013,
#   'post_vm_mv': -69.60103607177734,
#   'pre_noise_rms_mv': 0.036356788128614426,
#   'pre_vm_mv': -69.4753646850586,
#   'slow_noise_rms_mv': 0.5296552777290344,
#   'slow_vm_mv': -69.4753646850586,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[3]',
#   'stimulus_duration': 0.02801999999999999,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 93,
#   'vm_delta_mv': 0.12567138671875,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 1.4538558721542358,
#   'passed': True,
#   'post_noise_rms_mv': 0.03144555538892746,
#   'post_vm_mv': -70.04275512695312,
#   'pre_noise_rms_mv': 0.03253032639622688,
#   'pre_vm_mv': -69.9554672241211,
#   'slow_noise_rms_mv': 0.4764021635055542,
#   'slow_vm_mv': -69.9554672241211,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[4]',
#   'stimulus_duration': 0.025239999999999985,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 94,
#   'vm_delta_mv': 0.08728790283203125,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 6.194690227508545,
#   'passed': False,
#   'post_noise_rms_mv': 0.03320368379354477,
#   'post_vm_mv': -69.89404296875,
#   'pre_noise_rms_mv': 0.038037627935409546,
#   'pre_vm_mv': -69.7059326171875,
#   'slow_noise_rms_mv': 0.5610795617103577,
#   'slow_vm_mv': -69.7059326171875,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[5]',
#   'stimulus_duration': 0.023019999999999985,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 95,
#   'vm_delta_mv': 0.1881103515625,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 10.17699146270752,
#   'passed': True,
#   'post_noise_rms_mv': 0.036434534937143326,
#   'post_vm_mv': -69.2286148071289,
#   'pre_noise_rms_mv': 0.03391750901937485,
#   'pre_vm_mv': -69.19190216064453,
#   'slow_noise_rms_mv': 0.4157542288303375,
#   'slow_vm_mv': -69.19190216064453,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[6]',
#   'stimulus_duration': 0.021199999999999997,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 96,
#   'vm_delta_mv': 0.036712646484375,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 10.17699146270752,
#   'passed': True,
#   'post_noise_rms_mv': 0.03691725805401802,
#   'post_vm_mv': -68.98703002929688,
#   'pre_noise_rms_mv': 0.03607509285211563,
#   'pre_vm_mv': -68.64098358154297,
#   'slow_noise_rms_mv': 0.4743925929069519,
#   'slow_vm_mv': -68.64098358154297,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[7]',
#   'stimulus_duration': 0.019680000000000003,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 97,
#   'vm_delta_mv': 0.34604644775390625,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 10.17699146270752,
#   'passed': True,
#   'post_noise_rms_mv': 0.04029000177979469,
#   'post_vm_mv': -69.22103118896484,
#   'pre_noise_rms_mv': 0.039121709764003754,
#   'pre_vm_mv': -69.08506774902344,
#   'slow_noise_rms_mv': 0.3793075978755951,
#   'slow_vm_mv': -69.08506774902344,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[8]',
#   'stimulus_duration': 0.0184,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 98,
#   'vm_delta_mv': 0.13596343994140625,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 10.17699146270752,
#   'passed': False,
#   'post_noise_rms_mv': 0.03962349891662598,
#   'post_vm_mv': -69.36263275146484,
#   'pre_noise_rms_mv': 0.03535517677664757,
#   'pre_vm_mv': -68.93914794921875,
#   'slow_noise_rms_mv': 0.5387526154518127,
#   'slow_vm_mv': -68.93914794921875,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[9]',
#   'stimulus_duration': 0.017299999999999982,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 99,
#   'vm_delta_mv': 0.42348480224609375,
#   'peak_deflection': None,
#   'num_spikes': 3},
#  {'bridge_balance_mohm': 6.410256385803223,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 10.17699146270752,
#   'passed': True,
#   'post_noise_rms_mv': 0.0398440957069397,
#   'post_vm_mv': -69.01789093017578,
#   'pre_noise_rms_mv': 0.03741828724741936,
#   'pre_vm_mv': -68.80126953125,
#   'slow_noise_rms_mv': 0.4635099470615387,
#   'slow_vm_mv': -68.80126953125,
#   'stimulus_amplitude': 2115.0,
#   'stimulus_code': 'C2SSTRIPLE171103',
#   'stimulus_code_ext': 'C2SSTRIPLE171103[10]',
#   'stimulus_duration': 0.016339999999999993,
#   'stimulus_interval': nan,
#   'stimulus_name': 'Short Square - Triple',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 0.22,
#   'stimulus_units': 'Amps',
#   'sweep_number': 100,
#   'vm_delta_mv': 0.21662139892578125,
#   'peak_deflection': None,
#   'num_spikes': 3}]

# %%
def summarize_cell_ephys_features(lsa_results):
    hero_keep_features = ['adapt', 'avg_rate', 'first_isi', 'isi_cv', 'latency', 'mean_isi', 'median_isi', 
                          'stim_amp']
    rheo_keep_features = ['threshold_v', 'peak_v', 'trough_v', 
     'fast_trough_v', 'adp_vawww', 'width', 'upstroke_downstroke_ratio', 'peak_t', 'fast_trough_t', 'trough_t']
    
    overall_cell_keep_features = ['v_baseline', 'rheobase_i', 'fi_fit_slope', 
                                  'sag', 'vm_for_sag', 'input_resistance', 'tau']
    
    hero_small_dict = lsa_results['hero_sweep'][hero_keep_features]
    rheobase_sweep_index = lsa_results['rheobase_sweep'].name
    rheobase_sweep = lsa_results['spikes_set'][rheobase_sweep_index].iloc[0]
    
    rheo_spike_small_dict = rheobase_sweep[rheo_keep_features]
    rheo_first_isi = lsa_results['rheobase_sweep']['first_isi']
    rheo_spike_small_dict['rheo_first_isi'] = rheo_first_isi

    spike_comb_dict = {**hero_small_dict, **rheo_spike_small_dict}

    overall_cell_features = {x: lsa_results[x] for x in overall_cell_keep_features if x in lsa_results}
    final_cell_feature_dict = {**spike_comb_dict, **overall_cell_features}
    return(final_cell_feature_dict)

# %%
import urllib.request
from ipfx.dataset.create import create_ephys_data_set
from ipfx.utilities import drop_failed_sweeps

specimen_id = 720856118
row = file_manifest.query('cell_specimen_id == {} & technique == "intracellular_electrophysiology"'.format(specimen_id))
archive_uri = row['archive_uri'].values[0]
file_name = row['file_name'].values[0]
print('Intrinsic ephys file url: ' + archive_uri)
print('Intrinsic ephys file name: ' + file_name)

print('downloading data for cell from DANDI...')
try:
    urllib.request.urlretrieve(archive_uri, file_name)
    print('data downloaded!')

    # Create Ephys Data Set

    print('loading dataset into data structure...')
    #nwb_file_name = '/Users/stripathy/Downloads/sub-601462951_ses-601810292_icephys.nwb'
    data_set = create_ephys_data_set(nwb_file=file_name) ##loads nwb file into ipfx data structure

    # Drop failed sweeps: sweeps with incomplete recording or failing QC criteria
    drop_failed_sweeps(data_set)

    from ipfx.feature_extractor import SpikeFeatureExtractor, SpikeTrainFeatureExtractor

    import ipfx.stimulus_protocol_analysis as spa
    from ipfx.epochs import get_stim_epoch
    import matplotlib.pyplot as plt


    # get sweep table of Long Square sweeps
    long_square_table = data_set.filtered_sweep_table(
        stimuli=data_set.ontology.long_square_names
    )
    long_square_sweeps = data_set.sweep_set(long_square_table.sweep_number)

    # Select epoch corresponding to the actual recording from the sweeps
    # and align sweeps so that the experiment would start at the same time
    long_square_sweeps.select_epoch("recording")
    long_square_sweeps.align_to_start_of_epoch("experiment")

    # find the start and end time of the stimulus
    # (treating the first sweep as representative)
    stim_start_index, stim_end_index = get_stim_epoch(long_square_sweeps.i[0])
    stim_start_time = long_square_sweeps.t[0][stim_start_index]
    stim_end_time = long_square_sweeps.t[0][stim_end_index]

    # build the extractors
    spfx = SpikeFeatureExtractor(start=stim_start_time, end=stim_end_time)
    sptfx = SpikeTrainFeatureExtractor(start=stim_start_time, end=stim_end_time)

    # run the analysis and print out a few of the features
    long_square_analysis = spa.LongSquareAnalysis(spfx, sptfx, subthresh_min_amp=-100.0)
    data = long_square_analysis.analyze(long_square_sweeps)

    specimen_dict = summarize_cell_ephys_features(data)
    human_data_dict[specimen_id] = specimen_dict
    
except urllib.error.HTTPError as err:
    print(err.code)
# Out:
# Intrinsic ephys file url: https://girder.dandiarchive.org/api/v1/item/5edab0df2dace54b6f9b2b1e/download
# Intrinsic ephys file name: sub-720619787_ses-720856105_icephys.nwb
# downloading data for cell from DANDI...
# data downloaded!
# loading dataset into data structure...
# WARNING:root:sweep 56: ['Recording stopped before completing the experiment epoch']
# WARNING:root:sweep 57: ['Recording stopped before completing the experiment epoch']
# WARNING:root:sweep 58: ['Recording stopped before completing the experiment epoch']
# WARNING:root:sweep 59: ['Recording stopped before completing the experiment epoch']
# WARNING:root:sweep 60: ['Recording stopped before completing the experiment epoch']
# C:\Users\Allose\Anaconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-8866687c9f71> in <module>
#      54     # run the analysis and print out a few of the features
#      55     long_square_analysis = spa.LongSquareAnalysis(spfx, sptfx, subthresh_min_amp=-100.0)
# ---> 56     data = long_square_analysis.analyze(long_square_sweeps)
#      57
#      58     specimen_dict = summarize_cell_ephys_features(data)
#
# ~\Anaconda3\lib\site-packages\ipfx\stimulus_protocol_analysis.py in analyze(self, sweep_set)
#     129
#     130         extra_sweep_feature_names = ['peak_deflect','stim_amp','v_baseline','sag']
# --> 131         features = super(LongSquareAnalysis, self).analyze(sweep_set, extra_sweep_features=extra_sweep_feature_names)
#     132
#     133         features["v_baseline"] = np.nanmean(self._sweep_features["v_baseline"].values)
#
# ~\Anaconda3\lib\site-packages\ipfx\stimulus_protocol_analysis.py in analyze(self, sweep_set, extra_sweep_features, exclude_clipped)
#      82
#      83     def analyze(self, sweep_set, extra_sweep_features=None, exclude_clipped=False):
# ---> 84         self.analyze_basic_features(sweep_set, extra_sweep_features=extra_sweep_features, exclude_clipped=exclude_clipped)
#      85         return {"spikes_set": self._spikes_set, "sweeps": self._sweep_features}
#      86
#
# ~\Anaconda3\lib\site-packages\ipfx\stimulus_protocol_analysis.py in analyze_basic_features(self, sweep_set, extra_sweep_features, exclude_clipped)
#      72         self._spikes_set = []
#      73         for sweep in sweep_set.sweeps:
# ---> 74             self._spikes_set.append(self.spx.process(sweep.t, sweep.v, sweep.i))
#      75
#      76         self._sweep_features = pd.DataFrame([ self.sptx.process(sweep.t, sweep.v, sweep.i, spikes, extra_sweep_features, exclude_clipped=exclude_clipped)
#
# ~\Anaconda3\lib\site-packages\ipfx\feature_extractor.py in process(self, t, v, i)
#      91         putative_spikes = spkd.detect_putative_spikes(v, t, self.start, self.end,
#      92                                                     dv_cutoff=self.dv_cutoff,
# ---> 93                                                     dvdt=dvdt)
#      94         peaks = spkd.find_peak_indexes(v, t, putative_spikes, self.end)
#      95         putative_spikes, peaks = spkd.filter_putative_spikes(v, t, putative_spikes, peaks,
#
# ~\Anaconda3\lib\site-packages\ipfx\spike_detector.py in detect_putative_spikes(v, t, start, end, filter, dv_cutoff, dvdt)
#      38
#      39     start_index = tsu.find_time_index(t, start)
# ---> 40     end_index = tsu.find_time_index(t, end)
#      41     v_window = v[start_index:end_index + 1]
#      42     t_window = t[start_index:end_index + 1]
#
# ~\Anaconda3\lib\site-packages\ipfx\time_series_utils.py in find_time_index(t, t_0)
#      18     idx: index of t closest to t_0
#      19     """
# ---> 20     assert t[0] <= t_0 <= t[-1], "Given time ({:f}) is outside of time range ({:f}, {:f})".format(t_0, t[0], t[-1])
#      21
#      22     idx = np.argmin(abs(t - t_0))
#
# AssertionError: Given time (1.499980) is outside of time range (-0.520000, 1.238740)
