# %%
# Load IPFX libraries

from ipfx.dataset.create import create_ephys_data_set
from ipfx.data_set_features import extract_data_set_features
from ipfx.utilities import drop_failed_sweeps

# Load pandas library too
import pandas as pd

# %%
from ipfx.data_access import get_archive_info
archive_url, file_manifest, experiment_metadata = get_archive_info(dataset="mouse")

experiment_metadata.head()
# Out:
#       project  cell_specimen_id                 cell_specimen_name hemisphere  \
# 0  mIVSCC-MET         601506507  Vip-IRES-Cre;Ai14-331294.04.01.01       left
# 1  mIVSCC-MET         601790961  Sst-IRES-Cre;Ai14-331663.04.01.01       left
# 2  mIVSCC-MET         601803754  Sst-IRES-Cre;Ai14-331663.04.02.02      right
# 3  mIVSCC-MET         601808698  Sst-IRES-Cre;Ai14-331663.04.02.03      right
# 4  mIVSCC-MET         601810307  Sst-IRES-Cre;Ai14-331663.04.02.04      right
#
#   structure  donor_id                donor_name biological_sex  age  \
# 0    VISpm4    331294  Vip-IRES-Cre;Ai14-331294              M  P55
# 1    VISpm5    331663  Sst-IRES-Cre;Ai14-331663              F  P57
# 2   VISp2/3    331663  Sst-IRES-Cre;Ai14-331663              F  P57
# 3     VISp5    331663  Sst-IRES-Cre;Ai14-331663              F  P57
# 4   VISp2/3    331663  Sst-IRES-Cre;Ai14-331663              F  P57
#
#    ethnicity             ...                dendrite_type  \
# 0        NaN             ...               sparsely spiny
# 1        NaN             ...                       aspiny
# 2        NaN             ...               sparsely spiny
# 3        NaN             ...                       aspiny
# 4        NaN             ...                       aspiny
#
#   apical_dendrite_status neuron_reconstruction_type  \
# 0                    NaN                       full
# 1                    NaN                       full
# 2                    NaN                       full
# 3                    NaN                       full
# 4                    NaN                       full
#
#   cell_soma_normalized_depth depth_from_pia_um  ephys_session_id  \
# 0                   0.361015               NaN         601506492
# 1                   0.621829               NaN         601790945
# 2                   0.164240               NaN         601803733
# 3                   0.483030               NaN         601808619
# 4                   0.295656               NaN         601810292
#
#    transcriptomics_sample_id  transcriptomics_batch corresponding_AIT2.3.1_ID  \
# 0           PS0810_E1-50_S88                  BT035            CS180626100018
# 1           PS0817_E1-50_S19                  BT036            CS180626100041
# 2           PS0817_E1-50_S25                  BT036            CS180626100035
# 3           PS0817_E1-50_S26                  BT036            CS180626100043
# 4           PS0817_E1-50_S27                  BT036            CS180626100034
#
#   corresponding_AIT2.3.1_alias
# 0             Vip Gpc3 Slc18a3
# 1                Sst Tac2 Myh4
# 2             Sst Calb2 Pdlim5
# 3               Sst Hpse Cbln4
# 4             Sst Calb2 Necab1
#
# [5 rows x 22 columns]

# %%
import urllib.request

row = file_manifest.query('cell_specimen_id == 601790961 & technique == "intracellular_electrophysiology"')
archive_uri = row['archive_uri'].values[0]
file_name = row['file_name'].values[0]
print('Intrinsic ephys file url: ' + archive_uri)
print('Intrinsic ephys file name: ' + file_name)

print('downloading data for cell from DANDI...')
urllib.request.urlretrieve(archive_uri, file_name)
print('data downloaded!')
# Out:
# Intrinsic ephys file url: https://girder.dandiarchive.org/api/v1/item/5edb2e312dace54b6f9b39b3/download
# Intrinsic ephys file name: sub-601462951_ses-601790945_icephys.nwb
# downloading data for cell from DANDI...
# data downloaded!

# %%
from ipfx.dataset.create import create_ephys_data_set
from ipfx.utilities import drop_failed_sweeps

# Create Ephys Data Set

print('loading dataset into data structure...')
#nwb_file_name = '/Users/stripathy/Downloads/sub-601462951_ses-601810292_icephys.nwb'
data_set = create_ephys_data_set(nwb_file=file_name) ##loads nwb file into ipfx data structure

# Drop failed sweeps: sweeps with incomplete recording or failing QC criteria
drop_failed_sweeps(data_set)
# Out:
# loading dataset into data structure...

# %%
from ipfx.data_set_features import extract_data_set_features

# Calculate ephys features
cell_features, sweep_features, cell_record, sweep_records, _, _ = extract_data_set_features(data_set)

# print cell_record
sweep_records
# Out:
# C:\Users\Allose\Anaconda3\lib\site-packages\ipfx\spike_features.py:87: RuntimeWarning: invalid value encountered in less
#   width_levels[width_levels < v[spike_indexes]] = thresh_to_peak_levels[width_levels < v[spike_indexes]]
# C:\Users\Allose\Anaconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# C:\Users\Allose\Anaconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# C:\Users\Allose\Anaconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# [{'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': nan,
#   'passed': True,
#   'post_noise_rms_mv': 0.03975610062479973,
#   'post_vm_mv': -80.73778533935547,
#   'pre_noise_rms_mv': 0.04286888614296913,
#   'pre_vm_mv': -80.53914642333984,
#   'slow_noise_rms_mv': 0.23063915967941284,
#   'slow_vm_mv': -80.53914642333984,
#   'stimulus_amplitude': -110.0,
#   'stimulus_code': 'C1LSCOARSEMICRO',
#   'stimulus_code_ext': 'C1LSCOARSEMICRO[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 4,
#   'vm_delta_mv': 0.198638916015625,
#   'peak_deflection': -98.50000762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 1.8012222051620483,
#   'passed': True,
#   'post_noise_rms_mv': 0.04438219591975212,
#   'post_vm_mv': -81.40399169921875,
#   'pre_noise_rms_mv': 0.03746509924530983,
#   'pre_vm_mv': -80.99181365966797,
#   'slow_noise_rms_mv': 0.17039325833320618,
#   'slow_vm_mv': -80.99181365966797,
#   'stimulus_amplitude': -70.0,
#   'stimulus_code': 'C1LSCOARSEMICRO',
#   'stimulus_code_ext': 'C1LSCOARSEMICRO[1]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 5,
#   'vm_delta_mv': 0.41217803955078125,
#   'peak_deflection': -92.96875762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 3.7954328060150146,
#   'passed': False,
#   'post_noise_rms_mv': 0.03655017912387848,
#   'post_vm_mv': -79.21344757080078,
#   'pre_noise_rms_mv': 0.04494568705558777,
#   'pre_vm_mv': -80.8753662109375,
#   'slow_noise_rms_mv': 0.1489325761795044,
#   'slow_vm_mv': -80.8753662109375,
#   'stimulus_amplitude': -29.999998092651367,
#   'stimulus_code': 'C1LSCOARSEMICRO',
#   'stimulus_code_ext': 'C1LSCOARSEMICRO[2]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 6,
#   'vm_delta_mv': 1.6619186401367188,
#   'peak_deflection': -86.50000762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 3.7954328060150146,
#   'passed': True,
#   'post_noise_rms_mv': 0.039587173610925674,
#   'post_vm_mv': -81.62841796875,
#   'pre_noise_rms_mv': 0.05725695192813873,
#   'pre_vm_mv': -81.10746765136719,
#   'slow_noise_rms_mv': 0.19902783632278442,
#   'slow_vm_mv': -81.10746765136719,
#   'stimulus_amplitude': 10.0,
#   'stimulus_code': 'C1LSCOARSEMICRO',
#   'stimulus_code_ext': 'C1LSCOARSEMICRO[3]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 7,
#   'vm_delta_mv': 0.5209503173828125,
#   'peak_deflection': -77.00000762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 9.006111145019531,
#   'passed': True,
#   'post_noise_rms_mv': 0.04622277244925499,
#   'post_vm_mv': -80.9829330444336,
#   'pre_noise_rms_mv': 0.037282269448041916,
#   'pre_vm_mv': -81.58322143554688,
#   'slow_noise_rms_mv': 0.1260194033384323,
#   'slow_vm_mv': -81.58322143554688,
#   'stimulus_amplitude': 50.0,
#   'stimulus_code': 'C1LSCOARSEMICRO',
#   'stimulus_code_ext': 'C1LSCOARSEMICRO[4]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 8,
#   'vm_delta_mv': 0.6002883911132812,
#   'peak_deflection': -72.9375,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 11.386298179626465,
#   'passed': True,
#   'post_noise_rms_mv': 0.06387864798307419,
#   'post_vm_mv': -81.35910034179688,
#   'pre_noise_rms_mv': 0.034598302096128464,
#   'pre_vm_mv': -80.9232177734375,
#   'slow_noise_rms_mv': 0.4009602963924408,
#   'slow_vm_mv': -80.9232177734375,
#   'stimulus_amplitude': 90.0,
#   'stimulus_code': 'C1LSCOARSEMICRO',
#   'stimulus_code_ext': 'C1LSCOARSEMICRO[5]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 9,
#   'vm_delta_mv': 0.435882568359375,
#   'peak_deflection': -64.18750762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 13.57349681854248,
#   'passed': True,
#   'post_noise_rms_mv': 0.04488872364163399,
#   'post_vm_mv': -80.64775848388672,
#   'pre_noise_rms_mv': 0.03828850015997887,
#   'pre_vm_mv': -80.87552642822266,
#   'slow_noise_rms_mv': 0.2191266119480133,
#   'slow_vm_mv': -80.87552642822266,
#   'stimulus_amplitude': 130.0,
#   'stimulus_code': 'C1LSCOARSEMICRO',
#   'stimulus_code_ext': 'C1LSCOARSEMICRO[6]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 10,
#   'vm_delta_mv': 0.2277679443359375,
#   'peak_deflection': nan,
#   'num_spikes': 2},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 22.515277862548828,
#   'passed': False,
#   'post_noise_rms_mv': 0.04420669749379158,
#   'post_vm_mv': -81.001708984375,
#   'pre_noise_rms_mv': 0.045235130935907364,
#   'pre_vm_mv': -80.6209487915039,
#   'slow_noise_rms_mv': 0.6009010672569275,
#   'slow_vm_mv': -80.6209487915039,
#   'stimulus_amplitude': 119.99999237060547,
#   'stimulus_code': 'C1LSFINESTMICRO',
#   'stimulus_code_ext': 'C1LSFINESTMICRO[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 11,
#   'vm_delta_mv': 0.38076019287109375,
#   'peak_deflection': nan,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 24.57381820678711,
#   'passed': True,
#   'post_noise_rms_mv': 0.02675839699804783,
#   'post_vm_mv': -81.01294708251953,
#   'pre_noise_rms_mv': 0.0389845035970211,
#   'pre_vm_mv': -80.84368133544922,
#   'slow_noise_rms_mv': 0.15265299379825592,
#   'slow_vm_mv': -80.84368133544922,
#   'stimulus_amplitude': 110.0,
#   'stimulus_code': 'C1LSFINESTMICRO',
#   'stimulus_code_ext': 'C1LSFINESTMICRO[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 12,
#   'vm_delta_mv': 0.1692657470703125,
#   'peak_deflection': -58.3125,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 14.590965270996094,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 26.63235855102539,
#   'passed': True,
#   'post_noise_rms_mv': 0.042541515082120895,
#   'post_vm_mv': -80.5385971069336,
#   'pre_noise_rms_mv': 0.03475089743733406,
#   'pre_vm_mv': -80.39035034179688,
#   'slow_noise_rms_mv': 0.25908705592155457,
#   'slow_vm_mv': -80.39035034179688,
#   'stimulus_amplitude': 119.99999237060547,
#   'stimulus_code': 'C1LSFINESTMICRO',
#   'stimulus_code_ext': 'C1LSFINESTMICRO[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 13,
#   'vm_delta_mv': 0.14824676513671875,
#   'peak_deflection': nan,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 26.63235855102539,
#   'passed': True,
#   'post_noise_rms_mv': nan,
#   'post_vm_mv': nan,
#   'pre_noise_rms_mv': 0.034375011920928955,
#   'pre_vm_mv': -80.4739990234375,
#   'slow_noise_rms_mv': 0.1158147007226944,
#   'slow_vm_mv': -80.4739990234375,
#   'stimulus_amplitude': 142.875,
#   'stimulus_code': 'C1RP25PR1S141203',
#   'stimulus_code_ext': 'C1RP25PR1S141203[0]',
#   'stimulus_duration': 5.715,
#   'stimulus_interval': None,
#   'stimulus_name': 'Ramp',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.0225,
#   'stimulus_units': 'Amps',
#   'sweep_number': 14,
#   'vm_delta_mv': nan,
#   'peak_deflection': nan,
#   'num_spikes': 4},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 29.527179718017578,
#   'passed': True,
#   'post_noise_rms_mv': 0.04606952890753746,
#   'post_vm_mv': -80.75840759277344,
#   'pre_noise_rms_mv': 0.04507053270936012,
#   'pre_vm_mv': -80.78654479980469,
#   'slow_noise_rms_mv': 0.09112045168876648,
#   'slow_vm_mv': -80.78654479980469,
#   'stimulus_amplitude': 100.0,
#   'stimulus_code': 'C1SSCOARSE150112',
#   'stimulus_code_ext': 'C1SSCOARSE150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 15,
#   'vm_delta_mv': 0.02813720703125,
#   'peak_deflection': nan,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 29.527179718017578,
#   'passed': True,
#   'post_noise_rms_mv': 0.04163723066449165,
#   'post_vm_mv': -80.82765197753906,
#   'pre_noise_rms_mv': 0.040491681545972824,
#   'pre_vm_mv': -80.77217102050781,
#   'slow_noise_rms_mv': 0.0914364606142044,
#   'slow_vm_mv': -80.77217102050781,
#   'stimulus_amplitude': 200.0,
#   'stimulus_code': 'C1SSCOARSE150112',
#   'stimulus_code_ext': 'C1SSCOARSE150112[1]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 16,
#   'vm_delta_mv': 0.05548095703125,
#   'peak_deflection': nan,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 29.527179718017578,
#   'passed': True,
#   'post_noise_rms_mv': 0.037769753485918045,
#   'post_vm_mv': -81.0478515625,
#   'pre_noise_rms_mv': 0.03547511622309685,
#   'pre_vm_mv': -80.82227325439453,
#   'slow_noise_rms_mv': 0.11533486098051071,
#   'slow_vm_mv': -80.82227325439453,
#   'stimulus_amplitude': 300.0,
#   'stimulus_code': 'C1SSCOARSE150112',
#   'stimulus_code_ext': 'C1SSCOARSE150112[2]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 17,
#   'vm_delta_mv': 0.22557830810546875,
#   'peak_deflection': nan,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 29.527179718017578,
#   'passed': True,
#   'post_noise_rms_mv': 0.044162895530462265,
#   'post_vm_mv': -81.07572174072266,
#   'pre_noise_rms_mv': 0.03685958683490753,
#   'pre_vm_mv': -80.63369750976562,
#   'slow_noise_rms_mv': 0.30925682187080383,
#   'slow_vm_mv': -80.63369750976562,
#   'stimulus_amplitude': 400.0,
#   'stimulus_code': 'C1SSCOARSE150112',
#   'stimulus_code_ext': 'C1SSCOARSE150112[3]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 18,
#   'vm_delta_mv': 0.44202423095703125,
#   'peak_deflection': nan,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 31.650047302246094,
#   'passed': True,
#   'post_noise_rms_mv': 0.036901041865348816,
#   'post_vm_mv': -80.96785736083984,
#   'pre_noise_rms_mv': 0.04274935647845268,
#   'pre_vm_mv': -80.98760223388672,
#   'slow_noise_rms_mv': 0.26469314098358154,
#   'slow_vm_mv': -80.98760223388672,
#   'stimulus_amplitude': 499.9999694824219,
#   'stimulus_code': 'C1SSCOARSE150112',
#   'stimulus_code_ext': 'C1SSCOARSE150112[4]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 19,
#   'vm_delta_mv': 0.019744873046875,
#   'peak_deflection': nan,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 31.650047302246094,
#   'passed': True,
#   'post_noise_rms_mv': 0.04125699773430824,
#   'post_vm_mv': -81.1463623046875,
#   'pre_noise_rms_mv': 0.03234238177537918,
#   'pre_vm_mv': -81.00868225097656,
#   'slow_noise_rms_mv': 0.12337055057287216,
#   'slow_vm_mv': -81.00868225097656,
#   'stimulus_amplitude': 600.0,
#   'stimulus_code': 'C1SSCOARSE150112',
#   'stimulus_code_ext': 'C1SSCOARSE150112[5]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 20,
#   'vm_delta_mv': 0.1376800537109375,
#   'peak_deflection': nan,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.04157640412449837,
#   'post_vm_mv': -80.72818756103516,
#   'pre_noise_rms_mv': 0.041986510157585144,
#   'pre_vm_mv': -80.78343963623047,
#   'slow_noise_rms_mv': 0.09650642424821854,
#   'slow_vm_mv': -80.78343963623047,
#   'stimulus_amplitude': 550.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 21,
#   'vm_delta_mv': 0.0552520751953125,
#   'peak_deflection': nan,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.03378870338201523,
#   'post_vm_mv': -80.55377197265625,
#   'pre_noise_rms_mv': 0.04083806276321411,
#   'pre_vm_mv': -80.3033218383789,
#   'slow_noise_rms_mv': 0.1420029252767563,
#   'slow_vm_mv': -80.3033218383789,
#   'stimulus_amplitude': 570.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 22,
#   'vm_delta_mv': 0.25045013427734375,
#   'peak_deflection': nan,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.03082900121808052,
#   'post_vm_mv': -80.55258178710938,
#   'pre_noise_rms_mv': 0.03242050111293793,
#   'pre_vm_mv': -80.21395111083984,
#   'slow_noise_rms_mv': 0.07237270474433899,
#   'slow_vm_mv': -80.21395111083984,
#   'stimulus_amplitude': 560.0,
#   'stimulus_code': 'C1SSFINEST150112',
#   'stimulus_code_ext': 'C1SSFINEST150112[0]',
#   'stimulus_duration': 0.0029999999999998916,
#   'stimulus_interval': None,
#   'stimulus_name': 'Short Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 23,
#   'vm_delta_mv': 0.33863067626953125,
#   'peak_deflection': nan,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.03507586568593979,
#   'post_vm_mv': -80.39688110351562,
#   'pre_noise_rms_mv': 0.038975633680820465,
#   'pre_vm_mv': -80.17338562011719,
#   'slow_noise_rms_mv': 0.09369571506977081,
#   'slow_vm_mv': -80.17338562011719,
#   'stimulus_amplitude': -110.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 24,
#   'vm_delta_mv': 0.2234954833984375,
#   'peak_deflection': -97.625,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.04574447125196457,
#   'post_vm_mv': -80.01627349853516,
#   'pre_noise_rms_mv': 0.046459540724754333,
#   'pre_vm_mv': -80.22972106933594,
#   'slow_noise_rms_mv': 0.08881741762161255,
#   'slow_vm_mv': -80.22972106933594,
#   'stimulus_amplitude': -90.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[1]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 25,
#   'vm_delta_mv': 0.21344757080078125,
#   'peak_deflection': -94.75,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.04047137871384621,
#   'post_vm_mv': -79.34776306152344,
#   'pre_noise_rms_mv': 0.046333182603120804,
#   'pre_vm_mv': -79.79905700683594,
#   'slow_noise_rms_mv': 0.11005892604589462,
#   'slow_vm_mv': -79.79905700683594,
#   'stimulus_amplitude': -70.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[2]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 26,
#   'vm_delta_mv': 0.4512939453125,
#   'peak_deflection': -91.40625762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.029511844739317894,
#   'post_vm_mv': -80.35594177246094,
#   'pre_noise_rms_mv': 0.0437004379928112,
#   'pre_vm_mv': -79.59253692626953,
#   'slow_noise_rms_mv': 0.1129550114274025,
#   'slow_vm_mv': -79.59253692626953,
#   'stimulus_amplitude': -50.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[3]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 27,
#   'vm_delta_mv': 0.7634048461914062,
#   'peak_deflection': -87.96875,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.038452450186014175,
#   'post_vm_mv': -80.18492126464844,
#   'pre_noise_rms_mv': 0.03909491002559662,
#   'pre_vm_mv': -80.08643341064453,
#   'slow_noise_rms_mv': 0.11074021458625793,
#   'slow_vm_mv': -80.08643341064453,
#   'stimulus_amplitude': -29.999998092651367,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[4]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 28,
#   'vm_delta_mv': 0.09848785400390625,
#   'peak_deflection': -85.46875762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.03094291128218174,
#   'post_vm_mv': -79.96239471435547,
#   'pre_noise_rms_mv': 0.04302811622619629,
#   'pre_vm_mv': -79.96137237548828,
#   'slow_noise_rms_mv': 0.23206816613674164,
#   'slow_vm_mv': -79.96137237548828,
#   'stimulus_amplitude': -10.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[5]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 29,
#   'vm_delta_mv': 0.0010223388671875,
#   'peak_deflection': -82.06250762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.0367964431643486,
#   'post_vm_mv': -80.12171173095703,
#   'pre_noise_rms_mv': 0.04882942885160446,
#   'pre_vm_mv': -80.20745086669922,
#   'slow_noise_rms_mv': 0.07970850169658661,
#   'slow_vm_mv': -80.20745086669922,
#   'stimulus_amplitude': 10.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[6]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 30,
#   'vm_delta_mv': 0.0857391357421875,
#   'peak_deflection': -77.93750762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.03784603253006935,
#   'post_vm_mv': -80.26461029052734,
#   'pre_noise_rms_mv': 0.03486981615424156,
#   'pre_vm_mv': -80.20947265625,
#   'slow_noise_rms_mv': 0.10770931839942932,
#   'slow_vm_mv': -80.20947265625,
#   'stimulus_amplitude': 29.999998092651367,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[7]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 31,
#   'vm_delta_mv': 0.05513763427734375,
#   'peak_deflection': -74.15625762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.04045272246003151,
#   'post_vm_mv': -80.4246826171875,
#   'pre_noise_rms_mv': 0.036261770874261856,
#   'pre_vm_mv': -80.351806640625,
#   'slow_noise_rms_mv': 0.09155366569757462,
#   'slow_vm_mv': -80.351806640625,
#   'stimulus_amplitude': 50.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[8]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 32,
#   'vm_delta_mv': 0.0728759765625,
#   'peak_deflection': -71.40625,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.043047741055488586,
#   'post_vm_mv': -80.32756805419922,
#   'pre_noise_rms_mv': 0.039651840925216675,
#   'pre_vm_mv': -80.27339172363281,
#   'slow_noise_rms_mv': 0.1476539522409439,
#   'slow_vm_mv': -80.27339172363281,
#   'stimulus_amplitude': 70.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[9]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 33,
#   'vm_delta_mv': 0.05417633056640625,
#   'peak_deflection': -66.34375762939453,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.037115637212991714,
#   'post_vm_mv': -80.4993667602539,
#   'pre_noise_rms_mv': 0.043313369154930115,
#   'pre_vm_mv': -80.37539672851562,
#   'slow_noise_rms_mv': 0.11434920877218246,
#   'slow_vm_mv': -80.37539672851562,
#   'stimulus_amplitude': 90.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[10]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 34,
#   'vm_delta_mv': 0.12397003173828125,
#   'peak_deflection': -63.0,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.044456399977207184,
#   'post_vm_mv': -80.34382629394531,
#   'pre_noise_rms_mv': 0.038384631276130676,
#   'pre_vm_mv': -80.33684539794922,
#   'slow_noise_rms_mv': 0.08197497576475143,
#   'slow_vm_mv': -80.33684539794922,
#   'stimulus_amplitude': 110.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[11]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 35,
#   'vm_delta_mv': 0.00698089599609375,
#   'peak_deflection': nan,
#   'num_spikes': 1},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.03397664055228233,
#   'post_vm_mv': -80.16226196289062,
#   'pre_noise_rms_mv': 0.04340215399861336,
#   'pre_vm_mv': -80.08980560302734,
#   'slow_noise_rms_mv': 0.07995018362998962,
#   'slow_vm_mv': -80.08980560302734,
#   'stimulus_amplitude': 130.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[12]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 36,
#   'vm_delta_mv': 0.07245635986328125,
#   'peak_deflection': nan,
#   'num_spikes': 4},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.04038829356431961,
#   'post_vm_mv': -80.89075469970703,
#   'pre_noise_rms_mv': 0.032311391085386276,
#   'pre_vm_mv': -80.48351287841797,
#   'slow_noise_rms_mv': 0.07674603164196014,
#   'slow_vm_mv': -80.48351287841797,
#   'stimulus_amplitude': 150.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[13]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 37,
#   'vm_delta_mv': 0.4072418212890625,
#   'peak_deflection': nan,
#   'num_spikes': 8},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.04302565008401871,
#   'post_vm_mv': -80.52554321289062,
#   'pre_noise_rms_mv': 0.03760181739926338,
#   'pre_vm_mv': -80.58268737792969,
#   'slow_noise_rms_mv': 0.10424688458442688,
#   'slow_vm_mv': -80.58268737792969,
#   'stimulus_amplitude': 170.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[14]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 38,
#   'vm_delta_mv': 0.0571441650390625,
#   'peak_deflection': nan,
#   'num_spikes': 21},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 35.96011734008789,
#   'passed': True,
#   'post_noise_rms_mv': 0.03963807597756386,
#   'post_vm_mv': -80.89613342285156,
#   'pre_noise_rms_mv': 0.03787774220108986,
#   'pre_vm_mv': -80.79328155517578,
#   'slow_noise_rms_mv': 0.15859247744083405,
#   'slow_vm_mv': -80.79328155517578,
#   'stimulus_amplitude': 190.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[15]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 39,
#   'vm_delta_mv': 0.10285186767578125,
#   'peak_deflection': nan,
#   'num_spikes': 27},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 37.7613410949707,
#   'passed': True,
#   'post_noise_rms_mv': 0.03929554298520088,
#   'post_vm_mv': -80.69583892822266,
#   'pre_noise_rms_mv': 0.03571384400129318,
#   'pre_vm_mv': -80.78382110595703,
#   'slow_noise_rms_mv': 0.10023056715726852,
#   'slow_vm_mv': -80.78382110595703,
#   'stimulus_amplitude': 210.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[16]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 40,
#   'vm_delta_mv': 0.087982177734375,
#   'peak_deflection': nan,
#   'num_spikes': 35},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 37.7613410949707,
#   'passed': True,
#   'post_noise_rms_mv': 0.04153316840529442,
#   'post_vm_mv': -80.88646697998047,
#   'pre_noise_rms_mv': 0.03897532448172569,
#   'pre_vm_mv': -80.82109069824219,
#   'slow_noise_rms_mv': 0.08906641602516174,
#   'slow_vm_mv': -80.82109069824219,
#   'stimulus_amplitude': 230.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[17]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 41,
#   'vm_delta_mv': 0.06537628173828125,
#   'peak_deflection': nan,
#   'num_spikes': 44},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 37.7613410949707,
#   'passed': True,
#   'post_noise_rms_mv': 0.039740823209285736,
#   'post_vm_mv': -80.9168472290039,
#   'pre_noise_rms_mv': 0.039649177342653275,
#   'pre_vm_mv': -80.74671173095703,
#   'slow_noise_rms_mv': 0.06484544277191162,
#   'slow_vm_mv': -80.74671173095703,
#   'stimulus_amplitude': 249.99998474121094,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[18]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 42,
#   'vm_delta_mv': 0.170135498046875,
#   'peak_deflection': nan,
#   'num_spikes': 52},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 37.7613410949707,
#   'passed': True,
#   'post_noise_rms_mv': 0.038269832730293274,
#   'post_vm_mv': -80.49781036376953,
#   'pre_noise_rms_mv': 0.03560902178287506,
#   'pre_vm_mv': -80.21530151367188,
#   'slow_noise_rms_mv': 0.11037281900644302,
#   'slow_vm_mv': -80.21530151367188,
#   'stimulus_amplitude': 270.0,
#   'stimulus_code': 'C1LSCOARSE150216',
#   'stimulus_code_ext': 'C1LSCOARSE150216[19]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 43,
#   'vm_delta_mv': 0.28250885009765625,
#   'peak_deflection': nan,
#   'num_spikes': 63},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 37.7613410949707,
#   'passed': True,
#   'post_noise_rms_mv': 0.046583883464336395,
#   'post_vm_mv': -80.25242614746094,
#   'pre_noise_rms_mv': 0.04448021575808525,
#   'pre_vm_mv': -80.01920318603516,
#   'slow_noise_rms_mv': 0.2814202308654785,
#   'slow_vm_mv': -80.01920318603516,
#   'stimulus_amplitude': 100.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 44,
#   'vm_delta_mv': 0.23322296142578125,
#   'peak_deflection': -59.562503814697266,
#   'num_spikes': 0},
#  {'bridge_balance_mohm': 13.431013107299805,
#   'clamp_mode': 'CurrentClamp',
#   'leak_pa': 37.7613410949707,
#   'passed': True,
#   'post_noise_rms_mv': 0.04219068959355354,
#   'post_vm_mv': -80.40460205078125,
#   'pre_noise_rms_mv': 0.04081583395600319,
#   'pre_vm_mv': -80.09590148925781,
#   'slow_noise_rms_mv': 0.25770261883735657,
#   'slow_vm_mv': -80.09590148925781,
#   'stimulus_amplitude': 110.0,
#   'stimulus_code': 'C1LSFINEST150112',
#   'stimulus_code_ext': 'C1LSFINEST150112[0]',
#   'stimulus_duration': 0.9999999999999998,
#   'stimulus_interval': None,
#   'stimulus_name': 'Long Square',
#   'stimulus_scale_factor': 10.0,
#   'stimulus_start_time': 1.02,
#   'stimulus_units': 'Amps',
#   'sweep_number': 45,
#   'vm_delta_mv': 0.3087005615234375,
#   'peak_deflection': nan,
#   'num_spikes': 1}]

# %%
sweep_features
# Out:
# {4: {'spikes': [], 'sweep_number': 4, 'peak_deflect': (-98.50001, 60596)},
#  5: {'spikes': [], 'sweep_number': 5, 'peak_deflect': (-92.96876, 89497)},
#  6: {'spikes': [], 'sweep_number': 6, 'peak_deflect': (-86.50001, 75011)},
#  7: {'spikes': [], 'sweep_number': 7, 'peak_deflect': (-77.00001, 73623)},
#  8: {'spikes': [], 'sweep_number': 8, 'peak_deflect': (-72.9375, 68090)},
#  9: {'spikes': [], 'sweep_number': 9, 'peak_deflect': (-64.18751, 81613)},
#  10: {'spikes': [{'threshold_index': 53930,
#     'clipped': False,
#     'threshold_t': 0.5586,
#     'threshold_v': -53.781253814697266,
#     'threshold_i': 130,
#     'peak_index': 53949,
#     'peak_t': 0.55898,
#     'peak_v': 11.812500953674316,
#     'peak_i': 130,
#     'trough_index': 54015,
#     'trough_t': 0.5603,
#     'trough_v': -67.34375762939453,
#     'trough_i': 130,
#     'upstroke_index': 53941,
#     'upstroke': 352.1375715413927,
#     'upstroke_t': 0.5588199999999999,
#     'upstroke_v': -21.625001907348633,
#     'downstroke_index': 53962,
#     'downstroke': -170.13361050463578,
#     'downstroke_t': 0.55924,
#     'downstroke_v': -17.90625,
#     'isi_type': 'direct',
#     'fast_trough_index': 54011,
#     'fast_trough_t': 0.5602199999999999,
#     'fast_trough_v': -67.28125,
#     'fast_trough_i': 130,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0004999999999999449,
#     'upstroke_downstroke_ratio': 2.069770755448687},
#    {'threshold_index': 57969,
#     'clipped': False,
#     'threshold_t': 0.6393800000000001,
#     'threshold_v': -52.031253814697266,
#     'threshold_i': 130,
#     'peak_index': 57989,
#     'peak_t': 0.63978,
#     'peak_v': 11.84375,
#     'peak_i': 130,
#     'trough_index': 142425,
#     'trough_t': 2.3285,
#     'trough_v': -81.65625762939453,
#     'trough_i': 0,
#     'upstroke_index': 57980,
#     'upstroke': 329.20928672331866,
#     'upstroke_t': 0.6396,
#     'upstroke_v': -23.6875,
#     'downstroke_index': 58002,
#     'downstroke': -161.5658760343513,
#     'downstroke_t': 0.6400399999999999,
#     'downstroke_v': -16.375001907348633,
#     'isi_type': 'detour',
#     'fast_trough_index': 58052,
#     'fast_trough_t': 0.64104,
#     'fast_trough_v': -66.21875762939453,
#     'fast_trough_i': 130,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005399999999999849,
#     'upstroke_downstroke_ratio': 2.037616449734249}],
#   'sweep_number': 10},
#  11: {'spikes': [{'threshold_index': 56690,
#     'clipped': False,
#     'threshold_t': 0.6137999999999999,
#     'threshold_v': -53.000003814697266,
#     'threshold_i': 119.99999237060547,
#     'peak_index': 56709,
#     'peak_t': 0.61418,
#     'peak_v': 12.531250953674316,
#     'peak_i': 119.99999237060547,
#     'trough_index': 195351,
#     'trough_t': 3.38702,
#     'trough_v': -81.34375762939453,
#     'trough_i': 0,
#     'upstroke_index': 56700,
#     'upstroke': 348.9069346042817,
#     'upstroke_t': 0.6139999999999999,
#     'upstroke_v': -25.312501907348633,
#     'downstroke_index': 56722,
#     'downstroke': -168.01766197432332,
#     'downstroke_t': 0.6144399999999999,
#     'downstroke_v': -17.968751907348633,
#     'isi_type': 'detour',
#     'fast_trough_index': 56771,
#     'fast_trough_t': 0.6154200000000001,
#     'fast_trough_v': -66.96875762939453,
#     'fast_trough_i': 119.99999237060547,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000520000000000076,
#     'upstroke_downstroke_ratio': 2.0766086761616886}],
#   'sweep_number': 11},
#  12: {'spikes': [], 'sweep_number': 12, 'peak_deflect': (-58.3125, 57756)},
#  13: {'spikes': [{'threshold_index': 54855,
#     'clipped': False,
#     'threshold_t': 0.5771,
#     'threshold_v': -53.90625,
#     'threshold_i': 119.99999237060547,
#     'peak_index': 54874,
#     'peak_t': 0.57748,
#     'peak_v': 12.031250953674316,
#     'peak_i': 119.99999237060547,
#     'trough_index': 184038,
#     'trough_t': 3.16076,
#     'trough_v': -81,
#     'trough_i': 0,
#     'upstroke_index': 54865,
#     'upstroke': 353.20076932597397,
#     'upstroke_t': 0.5772999999999999,
#     'upstroke_v': -24.71875,
#     'downstroke_index': 54886,
#     'downstroke': -170.18625738129728,
#     'downstroke_t': 0.57772,
#     'downstroke_v': -16.34375,
#     'isi_type': 'detour',
#     'fast_trough_index': 54936,
#     'fast_trough_t': 0.5787199999999999,
#     'fast_trough_v': -67.4375,
#     'fast_trough_i': 119.99999237060547,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000520000000000076,
#     'upstroke_downstroke_ratio': 2.0753777347288276}],
#   'sweep_number': 13},
#  24: {'spikes': [], 'sweep_number': 24, 'peak_deflect': (-97.625, 87524)},
#  25: {'spikes': [], 'sweep_number': 25, 'peak_deflect': (-94.75, 58027)},
#  26: {'spikes': [], 'sweep_number': 26, 'peak_deflect': (-91.40626, 59442)},
#  27: {'spikes': [], 'sweep_number': 27, 'peak_deflect': (-87.96875, 68130)},
#  28: {'spikes': [], 'sweep_number': 28, 'peak_deflect': (-85.46876, 68679)},
#  29: {'spikes': [], 'sweep_number': 29, 'peak_deflect': (-82.06251, 92555)},
#  30: {'spikes': [], 'sweep_number': 30, 'peak_deflect': (-77.93751, 94333)},
#  31: {'spikes': [], 'sweep_number': 31, 'peak_deflect': (-74.15626, 100883)},
#  32: {'spikes': [], 'sweep_number': 32, 'peak_deflect': (-71.40625, 98837)},
#  33: {'spikes': [], 'sweep_number': 33, 'peak_deflect': (-66.34376, 57890)},
#  34: {'spikes': [], 'sweep_number': 34, 'peak_deflect': (-63.0, 58872)},
#  35: {'spikes': [{'threshold_index': 55103,
#     'clipped': False,
#     'threshold_t': 0.58206,
#     'threshold_v': -54.093753814697266,
#     'threshold_i': 110,
#     'peak_index': 55122,
#     'peak_t': 0.5824400000000001,
#     'peak_v': 6.78125,
#     'peak_i': 110,
#     'trough_index': 112265,
#     'trough_t': 1.7252999999999998,
#     'trough_v': -80.71875762939453,
#     'trough_i': 0,
#     'upstroke_index': 55113,
#     'upstroke': 316.98707527338877,
#     'upstroke_t': 0.58226,
#     'upstroke_v': -27.375001907348633,
#     'downstroke_index': 55135,
#     'downstroke': -150.91487869945715,
#     'downstroke_t': 0.5827,
#     'downstroke_v': -19.53125,
#     'isi_type': 'detour',
#     'fast_trough_index': 55187,
#     'fast_trough_t': 0.5837399999999999,
#     'fast_trough_v': -68.03125,
#     'fast_trough_i': 110,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005399999999999849,
#     'upstroke_downstroke_ratio': 2.1004362061918354}],
#   'sweep_number': 35},
#  36: {'spikes': [{'threshold_index': 53034,
#     'clipped': False,
#     'threshold_t': 0.54068,
#     'threshold_v': -54.437503814697266,
#     'threshold_i': 130,
#     'peak_index': 53053,
#     'peak_t': 0.5410599999999999,
#     'peak_v': 5.78125,
#     'peak_i': 130,
#     'trough_index': 53122,
#     'trough_t': 0.54244,
#     'trough_v': -67.5,
#     'trough_i': 130,
#     'upstroke_index': 53044,
#     'upstroke': 317.9063624527419,
#     'upstroke_t': 0.54088,
#     'upstroke_v': -29.281251907348633,
#     'downstroke_index': 53065,
#     'downstroke': -150.0445091746372,
#     'downstroke_t': 0.5412999999999999,
#     'downstroke_v': -17.65625,
#     'isi_type': 'direct',
#     'fast_trough_index': 53116,
#     'fast_trough_t': 0.5423199999999999,
#     'fast_trough_v': -67.21875,
#     'fast_trough_i': 130,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005399999999999849,
#     'upstroke_downstroke_ratio': 2.1187470584660306},
#    {'threshold_index': 54845,
#     'clipped': False,
#     'threshold_t': 0.5769,
#     'threshold_v': -53.4375,
#     'threshold_i': 130,
#     'peak_index': 54866,
#     'peak_t': 0.57732,
#     'peak_v': 5.468750476837158,
#     'peak_i': 130,
#     'trough_index': 54935,
#     'trough_t': 0.5787,
#     'trough_v': -66.59375,
#     'trough_i': 130,
#     'upstroke_index': 54856,
#     'upstroke': 296.31484922392127,
#     'upstroke_t': 0.5771200000000001,
#     'upstroke_v': -27.59375,
#     'downstroke_index': 54878,
#     'downstroke': -144.13188700571678,
#     'downstroke_t': 0.5775600000000001,
#     'downstroke_v': -18.531251907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 54932,
#     'fast_trough_t': 0.57864,
#     'fast_trough_v': -66.46875,
#     'fast_trough_i': 130,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000560000000000116,
#     'upstroke_downstroke_ratio': 2.055859084202293},
#    {'threshold_index': 58174,
#     'clipped': False,
#     'threshold_t': 0.64348,
#     'threshold_v': -51.187503814697266,
#     'threshold_i': 130,
#     'peak_index': 58195,
#     'peak_t': 0.6438999999999999,
#     'peak_v': 5.968750476837158,
#     'peak_i': 130,
#     'trough_index': 58267,
#     'trough_t': 0.64534,
#     'trough_v': -66.25000762939453,
#     'trough_i': 130,
#     'upstroke_index': 58185,
#     'upstroke': 281.0160311257713,
#     'upstroke_t': 0.6436999999999999,
#     'upstroke_v': -25.468751907348633,
#     'downstroke_index': 58207,
#     'downstroke': -138.95885765792147,
#     'downstroke_t': 0.6441399999999999,
#     'downstroke_v': -16.625,
#     'isi_type': 'direct',
#     'fast_trough_index': 58264,
#     'fast_trough_t': 0.6452800000000001,
#     'fast_trough_v': -66.12500762939453,
#     'fast_trough_i': 130,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005599999999998939,
#     'upstroke_downstroke_ratio': 2.0222966413379386},
#    {'threshold_index': 73963,
#     'clipped': False,
#     'threshold_t': 0.95926,
#     'threshold_v': -50.687503814697266,
#     'threshold_i': 130,
#     'peak_index': 73985,
#     'peak_t': 0.9597,
#     'peak_v': 6.437500476837158,
#     'peak_i': 130,
#     'trough_index': 113493,
#     'trough_t': 1.74986,
#     'trough_v': -80.75,
#     'trough_i': 0,
#     'upstroke_index': 73974,
#     'upstroke': 278.778116910877,
#     'upstroke_t': 0.9594799999999999,
#     'upstroke_v': -27.500001907348633,
#     'downstroke_index': 73997,
#     'downstroke': -138.99037436895227,
#     'downstroke_t': 0.95994,
#     'downstroke_v': -17.562501907348633,
#     'isi_type': 'detour',
#     'fast_trough_index': 74051,
#     'fast_trough_t': 0.96102,
#     'fast_trough_v': -65.5625,
#     'fast_trough_i': 130,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005800000000000249,
#     'upstroke_downstroke_ratio': 2.0057368589486333}],
#   'sweep_number': 36},
#  37: {'spikes': [{'threshold_index': 52437,
#     'clipped': False,
#     'threshold_t': 0.52874,
#     'threshold_v': -54.906253814697266,
#     'threshold_i': 150,
#     'peak_index': 52456,
#     'peak_t': 0.52912,
#     'peak_v': 5.78125,
#     'peak_i': 150,
#     'trough_index': 52526,
#     'trough_t': 0.5305199999999999,
#     'trough_v': -67.90625,
#     'trough_i': 150,
#     'upstroke_index': 52447,
#     'upstroke': 322.8275992898341,
#     'upstroke_t': 0.52894,
#     'upstroke_v': -28.843751907348633,
#     'downstroke_index': 52468,
#     'downstroke': -152.50943446723315,
#     'downstroke_t': 0.52936,
#     'downstroke_v': -18.65625,
#     'isi_type': 'direct',
#     'fast_trough_index': 52523,
#     'fast_trough_t': 0.5304599999999999,
#     'fast_trough_v': -67.8125,
#     'fast_trough_i': 150,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005399999999999849,
#     'upstroke_downstroke_ratio': 2.116771335606743},
#    {'threshold_index': 53611,
#     'clipped': False,
#     'threshold_t': 0.5522199999999999,
#     'threshold_v': -53.4375,
#     'threshold_i': 150,
#     'peak_index': 53632,
#     'peak_t': 0.55264,
#     'peak_v': 5.500000476837158,
#     'peak_i': 150,
#     'trough_index': 53703,
#     'trough_t': 0.55406,
#     'trough_v': -66.40625,
#     'trough_i': 150,
#     'upstroke_index': 53622,
#     'upstroke': 300.11882046679176,
#     'upstroke_t': 0.55244,
#     'upstroke_v': -27.5625,
#     'downstroke_index': 53644,
#     'downstroke': -142.49725019411267,
#     'downstroke_t': 0.55288,
#     'downstroke_v': -18.75,
#     'isi_type': 'direct',
#     'fast_trough_index': 53698,
#     'fast_trough_t': 0.55396,
#     'fast_trough_v': -66.31250762939453,
#     'fast_trough_i': 150,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000560000000000116,
#     'upstroke_downstroke_ratio': 2.1061376276241384},
#    {'threshold_index': 54921,
#     'clipped': False,
#     'threshold_t': 0.5784199999999999,
#     'threshold_v': -52.656253814697266,
#     'threshold_i': 150,
#     'peak_index': 54942,
#     'peak_t': 0.57884,
#     'peak_v': 5.468750476837158,
#     'peak_i': 150,
#     'trough_index': 55017,
#     'trough_t': 0.5803400000000001,
#     'trough_v': -66.09375,
#     'trough_i': 150,
#     'upstroke_index': 54933,
#     'upstroke': 283.50587359294445,
#     'upstroke_t': 0.57866,
#     'upstroke_v': -23.500001907348633,
#     'downstroke_index': 54955,
#     'downstroke': -138.92611906631032,
#     'downstroke_t': 0.5791,
#     'downstroke_v': -18.843751907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 55007,
#     'fast_trough_t': 0.5801399999999999,
#     'fast_trough_v': -65.93750762939453,
#     'fast_trough_i': 150,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005800000000000249,
#     'upstroke_downstroke_ratio': 2.0406952666519484},
#    {'threshold_index': 56937,
#     'clipped': False,
#     'threshold_t': 0.6187400000000001,
#     'threshold_v': -49.812503814697266,
#     'threshold_i': 150,
#     'peak_index': 56958,
#     'peak_t': 0.6191599999999999,
#     'peak_v': 5.406250476837158,
#     'peak_i': 150,
#     'trough_index': 57033,
#     'trough_t': 0.62066,
#     'trough_v': -65.81250762939453,
#     'trough_i': 150,
#     'upstroke_index': 56949,
#     'upstroke': 265.0393296617372,
#     'upstroke_t': 0.6189800000000001,
#     'upstroke_v': -22.21875,
#     'downstroke_index': 56971,
#     'downstroke': -133.21546348316141,
#     'downstroke_t': 0.6194200000000001,
#     'downstroke_v': -17.531251907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 57027,
#     'fast_trough_t': 0.6205400000000001,
#     'fast_trough_v': -65.71875762939453,
#     'fast_trough_i': 150,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005800000000000249,
#     'upstroke_downstroke_ratio': 1.9895537855125842},
#    {'threshold_index': 59876,
#     'clipped': False,
#     'threshold_t': 0.6775199999999999,
#     'threshold_v': -46.718753814697266,
#     'threshold_i': 150,
#     'peak_index': 59897,
#     'peak_t': 0.67794,
#     'peak_v': 5.218750476837158,
#     'peak_i': 150,
#     'trough_index': 59972,
#     'trough_t': 0.67944,
#     'trough_v': -65.09375762939453,
#     'trough_i': 150,
#     'upstroke_index': 59887,
#     'upstroke': 246.49530787454086,
#     'upstroke_t': 0.67774,
#     'upstroke_v': -23.312501907348633,
#     'downstroke_index': 59910,
#     'downstroke': -128.01564771976143,
#     'downstroke_t': 0.6781999999999999,
#     'downstroke_v': -17.46875,
#     'isi_type': 'direct',
#     'fast_trough_index': 59969,
#     'fast_trough_t': 0.6793799999999999,
#     'fast_trough_v': -65.00000762939453,
#     'fast_trough_i': 150,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005999999999999339,
#     'upstroke_downstroke_ratio': 1.9255092034853645},
#    {'threshold_index': 62497,
#     'clipped': False,
#     'threshold_t': 0.72994,
#     'threshold_v': -50.062503814697266,
#     'threshold_i': 150,
#     'peak_index': 62519,
#     'peak_t': 0.73038,
#     'peak_v': 5.656250476837158,
#     'peak_i': 150,
#     'trough_index': 62601,
#     'trough_t': 0.7320199999999999,
#     'trough_v': -65.53125,
#     'trough_i': 150,
#     'upstroke_index': 62509,
#     'upstroke': 262.8895306006602,
#     'upstroke_t': 0.73018,
#     'upstroke_v': -23.875001907348633,
#     'downstroke_index': 62532,
#     'downstroke': -134.532287702893,
#     'downstroke_t': 0.73064,
#     'downstroke_v': -18.562501907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 62588,
#     'fast_trough_t': 0.73176,
#     'fast_trough_v': -65.375,
#     'fast_trough_i': 150,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005999999999999339,
#     'upstroke_downstroke_ratio': 1.954099904858802},
#    {'threshold_index': 75409,
#     'clipped': False,
#     'threshold_t': 0.9881800000000001,
#     'threshold_v': -50.25,
#     'threshold_i': 150,
#     'peak_index': 75430,
#     'peak_t': 0.9885999999999999,
#     'peak_v': 5.875000476837158,
#     'peak_i': 150,
#     'trough_index': 75510,
#     'trough_t': 0.9902,
#     'trough_v': -65.25,
#     'trough_i': 150,
#     'upstroke_index': 75420,
#     'upstroke': 263.85614620120157,
#     'upstroke_t': 0.9884,
#     'upstroke_v': -27.031251907348633,
#     'downstroke_index': 75443,
#     'downstroke': -131.48664306080238,
#     'downstroke_t': 0.9888600000000001,
#     'downstroke_v': -16.218751907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 75503,
#     'fast_trough_t': 0.9900599999999999,
#     'fast_trough_v': -65.15625,
#     'fast_trough_i': 150,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005999999999999339,
#     'upstroke_downstroke_ratio': 2.0067144468749465},
#    {'threshold_index': 94737,
#     'clipped': False,
#     'threshold_t': 1.37474,
#     'threshold_v': -49.28125,
#     'threshold_i': 150,
#     'peak_index': 94758,
#     'peak_t': 1.37516,
#     'peak_v': 6.0,
#     'peak_i': 150,
#     'trough_index': 111644,
#     'trough_t': 1.7128800000000002,
#     'trough_v': -81.65625762939453,
#     'trough_i': 0,
#     'upstroke_index': 94748,
#     'upstroke': 264.51409615874275,
#     'upstroke_t': 1.37496,
#     'upstroke_v': -26.687501907348633,
#     'downstroke_index': 94772,
#     'downstroke': -132.63358529014138,
#     'downstroke_t': 1.37544,
#     'downstroke_v': -19.3125,
#     'isi_type': 'detour',
#     'fast_trough_index': 94830,
#     'fast_trough_t': 1.3766,
#     'fast_trough_v': -65.21875762939453,
#     'fast_trough_i': 150,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005800000000000249,
#     'upstroke_downstroke_ratio': 1.9943221438228287}],
#   'sweep_number': 37},
#  38: {'spikes': [{'threshold_index': 52020,
#     'clipped': False,
#     'threshold_t': 0.5204,
#     'threshold_v': -54.843753814697266,
#     'threshold_i': 170,
#     'peak_index': 52040,
#     'peak_t': 0.5207999999999999,
#     'peak_v': 5.375,
#     'peak_i': 170,
#     'trough_index': 52105,
#     'trough_t': 0.5221,
#     'trough_v': -67.84375,
#     'trough_i': 170,
#     'upstroke_index': 52031,
#     'upstroke': 318.0527159958353,
#     'upstroke_t': 0.5206200000000001,
#     'upstroke_v': -25.84375,
#     'downstroke_index': 52052,
#     'downstroke': -154.31807935628663,
#     'downstroke_t': 0.52104,
#     'downstroke_v': -20.875001907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 52104,
#     'fast_trough_t': 0.5220799999999999,
#     'fast_trough_v': -67.75000762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000520000000000076,
#     'upstroke_downstroke_ratio': 2.061020441172815},
#    {'threshold_index': 52866,
#     'clipped': False,
#     'threshold_t': 0.53732,
#     'threshold_v': -53.6875,
#     'threshold_i': 170,
#     'peak_index': 52887,
#     'peak_t': 0.5377399999999999,
#     'peak_v': 5.250000476837158,
#     'peak_i': 170,
#     'trough_index': 52956,
#     'trough_t': 0.53912,
#     'trough_v': -66.62500762939453,
#     'trough_i': 170,
#     'upstroke_index': 52877,
#     'upstroke': 298.1480904858286,
#     'upstroke_t': 0.5375399999999999,
#     'upstroke_v': -28.281251907348633,
#     'downstroke_index': 52899,
#     'downstroke': -142.80228724611126,
#     'downstroke_t': 0.5379799999999999,
#     'downstroke_v': -18.843751907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 52951,
#     'fast_trough_t': 0.53902,
#     'fast_trough_v': -66.53125762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005599999999998939,
#     'upstroke_downstroke_ratio': 2.0878383409362913},
#    {'threshold_index': 53808,
#     'clipped': False,
#     'threshold_t': 0.55616,
#     'threshold_v': -52.468753814697266,
#     'threshold_i': 170,
#     'peak_index': 53829,
#     'peak_t': 0.5565800000000001,
#     'peak_v': 5.031250476837158,
#     'peak_i': 170,
#     'trough_index': 53899,
#     'trough_t': 0.5579799999999999,
#     'trough_v': -65.71875762939453,
#     'trough_i': 170,
#     'upstroke_index': 53820,
#     'upstroke': 280.7186946947027,
#     'upstroke_t': 0.5564,
#     'upstroke_v': -23.937501907348633,
#     'downstroke_index': 53842,
#     'downstroke': -134.8560298782525,
#     'downstroke_t': 0.55684,
#     'downstroke_v': -18.46875,
#     'isi_type': 'direct',
#     'fast_trough_index': 53896,
#     'fast_trough_t': 0.55792,
#     'fast_trough_v': -65.62500762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005800000000000249,
#     'upstroke_downstroke_ratio': 2.0816176699561333},
#    {'threshold_index': 54870,
#     'clipped': False,
#     'threshold_t': 0.5773999999999999,
#     'threshold_v': -51.875003814697266,
#     'threshold_i': 170,
#     'peak_index': 54892,
#     'peak_t': 0.5778399999999999,
#     'peak_v': 5.000000476837158,
#     'peak_i': 170,
#     'trough_index': 54968,
#     'trough_t': 0.5793599999999999,
#     'trough_v': -65.40625762939453,
#     'trough_i': 170,
#     'upstroke_index': 54882,
#     'upstroke': 268.47086317932815,
#     'upstroke_t': 0.5776399999999999,
#     'upstroke_v': -27.406251907348633,
#     'downstroke_index': 54905,
#     'downstroke': -130.94928345258393,
#     'downstroke_t': 0.5781000000000001,
#     'downstroke_v': -17.78125,
#     'isi_type': 'direct',
#     'fast_trough_index': 54960,
#     'fast_trough_t': 0.5791999999999999,
#     'fast_trough_v': -65.31250762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005800000000000249,
#     'upstroke_downstroke_ratio': 2.0501896314426196},
#    {'threshold_index': 56137,
#     'clipped': False,
#     'threshold_t': 0.60274,
#     'threshold_v': -50.187503814697266,
#     'threshold_i': 170,
#     'peak_index': 56159,
#     'peak_t': 0.60318,
#     'peak_v': 4.90625,
#     'peak_i': 170,
#     'trough_index': 56231,
#     'trough_t': 0.6046199999999999,
#     'trough_v': -64.84375,
#     'trough_i': 170,
#     'upstroke_index': 56148,
#     'upstroke': 258.1388931299059,
#     'upstroke_t': 0.6029599999999999,
#     'upstroke_v': -27.500001907348633,
#     'downstroke_index': 56171,
#     'downstroke': -129.98972258791167,
#     'downstroke_t': 0.6034200000000001,
#     'downstroke_v': -17.15625,
#     'isi_type': 'direct',
#     'fast_trough_index': 56225,
#     'fast_trough_t': 0.6045,
#     'fast_trough_v': -64.68750762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005999999999999339,
#     'upstroke_downstroke_ratio': 1.9858407879540425},
#    {'threshold_index': 57495,
#     'clipped': False,
#     'threshold_t': 0.6298999999999999,
#     'threshold_v': -50.625003814697266,
#     'threshold_i': 170,
#     'peak_index': 57517,
#     'peak_t': 0.6303399999999999,
#     'peak_v': 4.781250476837158,
#     'peak_i': 170,
#     'trough_index': 57593,
#     'trough_t': 0.6318600000000001,
#     'trough_v': -65.09375762939453,
#     'trough_i': 170,
#     'upstroke_index': 57507,
#     'upstroke': 256.41025864869016,
#     'upstroke_t': 0.6301399999999999,
#     'upstroke_v': -26.343751907348633,
#     'downstroke_index': 57530,
#     'downstroke': -127.57838512817453,
#     'downstroke_t': 0.6306,
#     'downstroke_v': -16.937501907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 57587,
#     'fast_trough_t': 0.63174,
#     'fast_trough_v': -64.9375,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005999999999999339,
#     'upstroke_downstroke_ratio': 2.009825241094577},
#    {'threshold_index': 59279,
#     'clipped': False,
#     'threshold_t': 0.6655800000000001,
#     'threshold_v': -46.875003814697266,
#     'threshold_i': 170,
#     'peak_index': 59301,
#     'peak_t': 0.6660200000000001,
#     'peak_v': 4.625,
#     'peak_i': 170,
#     'trough_index': 59376,
#     'trough_t': 0.6675199999999999,
#     'trough_v': -64.28125762939453,
#     'trough_i': 170,
#     'upstroke_index': 59291,
#     'upstroke': 235.06843893299464,
#     'upstroke_t': 0.6658200000000001,
#     'upstroke_v': -21.53125,
#     'downstroke_index': 59314,
#     'downstroke': -124.01312153601195,
#     'downstroke_t': 0.66628,
#     'downstroke_v': -17.406251907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 59367,
#     'fast_trough_t': 0.66734,
#     'fast_trough_v': -64.06250762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006199999999998429,
#     'upstroke_downstroke_ratio': 1.8955126362554588},
#    {'threshold_index': 61120,
#     'clipped': False,
#     'threshold_t': 0.7023999999999999,
#     'threshold_v': -48.593753814697266,
#     'threshold_i': 170,
#     'peak_index': 61142,
#     'peak_t': 0.7028399999999999,
#     'peak_v': 4.718750476837158,
#     'peak_i': 170,
#     'trough_index': 61217,
#     'trough_t': 0.70434,
#     'trough_v': -64.59375762939453,
#     'trough_i': 170,
#     'upstroke_index': 61132,
#     'upstroke': 243.00352513764614,
#     'upstroke_t': 0.7026399999999999,
#     'upstroke_v': -22.40625,
#     'downstroke_index': 61155,
#     'downstroke': -123.3835012420368,
#     'downstroke_t': 0.7031000000000001,
#     'downstroke_v': -17.46875,
#     'isi_type': 'direct',
#     'fast_trough_index': 61211,
#     'fast_trough_t': 0.7042200000000001,
#     'fast_trough_v': -64.50000762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006200000000000649,
#     'upstroke_downstroke_ratio': 1.9694977261259203},
#    {'threshold_index': 63214,
#     'clipped': False,
#     'threshold_t': 0.74428,
#     'threshold_v': -48.593753814697266,
#     'threshold_i': 170,
#     'peak_index': 63237,
#     'peak_t': 0.74474,
#     'peak_v': 4.84375,
#     'peak_i': 170,
#     'trough_index': 63311,
#     'trough_t': 0.7462199999999999,
#     'trough_v': -64.5625,
#     'trough_i': 170,
#     'upstroke_index': 63226,
#     'upstroke': 239.7586774938211,
#     'upstroke_t': 0.7445200000000001,
#     'upstroke_v': -25.906251907348633,
#     'downstroke_index': 63250,
#     'downstroke': -125.83451896067255,
#     'downstroke_t': 0.7449999999999999,
#     'downstroke_v': -17.531251907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 63309,
#     'fast_trough_t': 0.7461800000000001,
#     'fast_trough_v': -64.53125,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006200000000000649,
#     'upstroke_downstroke_ratio': 1.9053490208736255},
#    {'threshold_index': 65722,
#     'clipped': False,
#     'threshold_t': 0.79444,
#     'threshold_v': -46.09375,
#     'threshold_i': 170,
#     'peak_index': 65744,
#     'peak_t': 0.79488,
#     'peak_v': 4.562500476837158,
#     'peak_i': 170,
#     'trough_index': 65819,
#     'trough_t': 0.7963800000000001,
#     'trough_v': -64.18750762939453,
#     'trough_i': 170,
#     'upstroke_index': 65734,
#     'upstroke': 227.66965709115803,
#     'upstroke_t': 0.79468,
#     'upstroke_v': -23.09375,
#     'downstroke_index': 65757,
#     'downstroke': -122.58203644466232,
#     'downstroke_t': 0.79514,
#     'downstroke_v': -16.3125,
#     'isi_type': 'direct',
#     'fast_trough_index': 65814,
#     'fast_trough_t': 0.7962799999999999,
#     'fast_trough_v': -64.03125,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006200000000000649,
#     'upstroke_downstroke_ratio': 1.857284017254321},
#    {'threshold_index': 68312,
#     'clipped': False,
#     'threshold_t': 0.8462399999999999,
#     'threshold_v': -47.718753814697266,
#     'threshold_i': 170,
#     'peak_index': 68335,
#     'peak_t': 0.8467,
#     'peak_v': 4.4375,
#     'peak_i': 170,
#     'trough_index': 68411,
#     'trough_t': 0.84822,
#     'trough_v': -64.18750762939453,
#     'trough_i': 170,
#     'upstroke_index': 68324,
#     'upstroke': 233.83443169526169,
#     'upstroke_t': 0.8464799999999999,
#     'upstroke_v': -23.906251907348633,
#     'downstroke_index': 68347,
#     'downstroke': -122.4339209058321,
#     'downstroke_t': 0.84694,
#     'downstroke_v': -15.718750953674316,
#     'isi_type': 'direct',
#     'fast_trough_index': 68402,
#     'fast_trough_t': 0.8480399999999999,
#     'fast_trough_v': -64.03125,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006199999999998429,
#     'upstroke_downstroke_ratio': 1.9098827348273142},
#    {'threshold_index': 70542,
#     'clipped': False,
#     'threshold_t': 0.8908400000000001,
#     'threshold_v': -48.468753814697266,
#     'threshold_i': 170,
#     'peak_index': 70565,
#     'peak_t': 0.8913,
#     'peak_v': 4.875,
#     'peak_i': 170,
#     'trough_index': 70637,
#     'trough_t': 0.8927400000000001,
#     'trough_v': -64.34375,
#     'trough_i': 170,
#     'upstroke_index': 70554,
#     'upstroke': 240.0534033614306,
#     'upstroke_t': 0.8910799999999999,
#     'upstroke_v': -26.0,
#     'downstroke_index': 70578,
#     'downstroke': -126.42578285214164,
#     'downstroke_t': 0.8915599999999999,
#     'downstroke_v': -18.000001907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 70636,
#     'fast_trough_t': 0.89272,
#     'fast_trough_v': -64.28125762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005999999999999339,
#     'upstroke_downstroke_ratio': 1.8987693644909405},
#    {'threshold_index': 73283,
#     'clipped': False,
#     'threshold_t': 0.94566,
#     'threshold_v': -46.843753814697266,
#     'threshold_i': 170,
#     'peak_index': 73306,
#     'peak_t': 0.9461200000000001,
#     'peak_v': 4.812500476837158,
#     'peak_i': 170,
#     'trough_index': 73381,
#     'trough_t': 0.9476199999999999,
#     'trough_v': -64.21875,
#     'trough_i': 170,
#     'upstroke_index': 73295,
#     'upstroke': 229.09427374423385,
#     'upstroke_t': 0.9459,
#     'upstroke_v': -24.40625,
#     'downstroke_index': 73319,
#     'downstroke': -123.06481931516231,
#     'downstroke_t': 0.94638,
#     'downstroke_v': -17.562501907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 73373,
#     'fast_trough_t': 0.94746,
#     'fast_trough_v': -64.03125,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006200000000000649,
#     'upstroke_downstroke_ratio': 1.8615740470681217},
#    {'threshold_index': 76223,
#     'clipped': False,
#     'threshold_t': 1.00446,
#     'threshold_v': -46.8125,
#     'threshold_i': 170,
#     'peak_index': 76246,
#     'peak_t': 1.00492,
#     'peak_v': 4.6875,
#     'peak_i': 170,
#     'trough_index': 76328,
#     'trough_t': 1.00656,
#     'trough_v': -64.40625,
#     'trough_i': 170,
#     'upstroke_index': 76235,
#     'upstroke': 233.1419838144004,
#     'upstroke_t': 1.0047,
#     'upstroke_v': -24.6875,
#     'downstroke_index': 76259,
#     'downstroke': -123.04989691445796,
#     'downstroke_t': 1.00518,
#     'downstroke_v': -17.65625,
#     'isi_type': 'direct',
#     'fast_trough_index': 76316,
#     'fast_trough_t': 1.0063199999999999,
#     'fast_trough_v': -64.15625762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000640000000000196,
#     'upstroke_downstroke_ratio': 1.8946946698905114},
#    {'threshold_index': 79583,
#     'clipped': False,
#     'threshold_t': 1.07166,
#     'threshold_v': -45.843753814697266,
#     'threshold_i': 170,
#     'peak_index': 79605,
#     'peak_t': 1.0721,
#     'peak_v': 4.84375,
#     'peak_i': 170,
#     'trough_index': 79682,
#     'trough_t': 1.07364,
#     'trough_v': -64.34375,
#     'trough_i': 170,
#     'upstroke_index': 79594,
#     'upstroke': 229.36064576296968,
#     'upstroke_t': 1.07188,
#     'upstroke_v': -24.593751907348633,
#     'downstroke_index': 79618,
#     'downstroke': -123.91325971765562,
#     'downstroke_t': 1.07236,
#     'downstroke_v': -17.375001907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 79677,
#     'fast_trough_t': 1.07354,
#     'fast_trough_v': -64.15625762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006399999999999739,
#     'upstroke_downstroke_ratio': 1.850977419895036},
#    {'threshold_index': 82697,
#     'clipped': False,
#     'threshold_t': 1.13394,
#     'threshold_v': -47.093753814697266,
#     'threshold_i': 170,
#     'peak_index': 82719,
#     'peak_t': 1.13438,
#     'peak_v': 4.718750476837158,
#     'peak_i': 170,
#     'trough_index': 82798,
#     'trough_t': 1.13596,
#     'trough_v': -64.34375,
#     'trough_i': 170,
#     'upstroke_index': 82709,
#     'upstroke': 234.33083056703103,
#     'upstroke_t': 1.13418,
#     'upstroke_v': -22.375,
#     'downstroke_index': 82732,
#     'downstroke': -124.42268013592285,
#     'downstroke_t': 1.13464,
#     'downstroke_v': -16.875,
#     'isi_type': 'direct',
#     'fast_trough_index': 82788,
#     'fast_trough_t': 1.1357599999999999,
#     'fast_trough_v': -64.06250762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006200000000000649,
#     'upstroke_downstroke_ratio': 1.8833449842990153},
#    {'threshold_index': 85972,
#     'clipped': False,
#     'threshold_t': 1.19944,
#     'threshold_v': -46.96875,
#     'threshold_i': 170,
#     'peak_index': 85994,
#     'peak_t': 1.19988,
#     'peak_v': 4.812500476837158,
#     'peak_i': 170,
#     'trough_index': 86076,
#     'trough_t': 1.20152,
#     'trough_v': -64.40625,
#     'trough_i': 170,
#     'upstroke_index': 85984,
#     'upstroke': 232.25758072113388,
#     'upstroke_t': 1.19968,
#     'upstroke_v': -21.437501907348633,
#     'downstroke_index': 86007,
#     'downstroke': -123.26857333452107,
#     'downstroke_t': 1.20014,
#     'downstroke_v': -16.03125,
#     'isi_type': 'direct',
#     'fast_trough_index': 86068,
#     'fast_trough_t': 1.20136,
#     'fast_trough_v': -64.37500762939453,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006199999999998429,
#     'upstroke_downstroke_ratio': 1.884158909593632},
#    {'threshold_index': 89904,
#     'clipped': False,
#     'threshold_t': 1.2780799999999999,
#     'threshold_v': -45.875,
#     'threshold_i': 170,
#     'peak_index': 89927,
#     'peak_t': 1.27854,
#     'peak_v': 4.281250476837158,
#     'peak_i': 170,
#     'trough_index': 90003,
#     'trough_t': 1.28006,
#     'trough_v': -64.03125,
#     'trough_i': 170,
#     'upstroke_index': 89916,
#     'upstroke': 223.27457406441567,
#     'upstroke_t': 1.27832,
#     'upstroke_v': -23.312501907348633,
#     'downstroke_index': 89939,
#     'downstroke': -120.60583649780278,
#     'downstroke_t': 1.27878,
#     'downstroke_v': -15.500000953674316,
#     'isi_type': 'direct',
#     'fast_trough_index': 90000,
#     'fast_trough_t': 1.28,
#     'fast_trough_v': -63.9375,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006399999999999739,
#     'upstroke_downstroke_ratio': 1.8512750340111719},
#    {'threshold_index': 93236,
#     'clipped': False,
#     'threshold_t': 1.34472,
#     'threshold_v': -47.250003814697266,
#     'threshold_i': 170,
#     'peak_index': 93259,
#     'peak_t': 1.34518,
#     'peak_v': 5.000000476837158,
#     'peak_i': 170,
#     'trough_index': 93337,
#     'trough_t': 1.34674,
#     'trough_v': -64.34375,
#     'trough_i': 170,
#     'upstroke_index': 93248,
#     'upstroke': 235.677006374907,
#     'upstroke_t': 1.34496,
#     'upstroke_v': -24.6875,
#     'downstroke_index': 93272,
#     'downstroke': -125.18182188921955,
#     'downstroke_t': 1.34544,
#     'downstroke_v': -17.562501907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 93331,
#     'fast_trough_t': 1.34662,
#     'fast_trough_v': -64.21875,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006200000000000649,
#     'upstroke_downstroke_ratio': 1.8826775550804082},
#    {'threshold_index': 96366,
#     'clipped': False,
#     'threshold_t': 1.40732,
#     'threshold_v': -46.25,
#     'threshold_i': 170,
#     'peak_index': 96388,
#     'peak_t': 1.40776,
#     'peak_v': 4.875,
#     'peak_i': 170,
#     'trough_index': 96465,
#     'trough_t': 1.4093,
#     'trough_v': -64.09375,
#     'trough_i': 170,
#     'upstroke_index': 96377,
#     'upstroke': 232.2153953855511,
#     'upstroke_t': 1.40754,
#     'upstroke_v': -24.71875,
#     'downstroke_index': 96401,
#     'downstroke': -123.95090345030806,
#     'downstroke_t': 1.40802,
#     'downstroke_v': -17.21875,
#     'isi_type': 'direct',
#     'fast_trough_index': 96458,
#     'fast_trough_t': 1.40916,
#     'fast_trough_v': -64.0,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006399999999999739,
#     'upstroke_downstroke_ratio': 1.8734465737770623},
#    {'threshold_index': 100170,
#     'clipped': False,
#     'threshold_t': 1.4834,
#     'threshold_v': -45.593753814697266,
#     'threshold_i': 170,
#     'peak_index': 100192,
#     'peak_t': 1.4838399999999998,
#     'peak_v': 4.343750476837158,
#     'peak_i': 170,
#     'trough_index': 108965,
#     'trough_t': 1.6593,
#     'trough_v': -83.31250762939453,
#     'trough_i': 0,
#     'upstroke_index': 100182,
#     'upstroke': 221.08994069184027,
#     'upstroke_t': 1.4836399999999998,
#     'upstroke_v': -20.562501907348633,
#     'downstroke_index': 100205,
#     'downstroke': -120.4962972135995,
#     'downstroke_t': 1.4841000000000002,
#     'downstroke_v': -16.59375,
#     'isi_type': 'detour',
#     'fast_trough_index': 100266,
#     'fast_trough_t': 1.4853200000000002,
#     'fast_trough_v': -63.84375,
#     'fast_trough_i': 170,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000640000000000196,
#     'upstroke_downstroke_ratio': 1.8348276735833797}],
#   'sweep_number': 38},
#  39: {'spikes': [{'threshold_index': 51836,
#     'clipped': False,
#     'threshold_t': 0.5167200000000001,
#     'threshold_v': -55.718753814697266,
#     'threshold_i': 190,
#     'peak_index': 51855,
#     'peak_t': 0.5170999999999999,
#     'peak_v': 7.718750476837158,
#     'peak_i': 190,
#     'trough_index': 51919,
#     'trough_t': 0.5183800000000001,
#     'trough_v': -68.46875762939453,
#     'trough_i': 190,
#     'upstroke_index': 51847,
#     'upstroke': 344.79988693041736,
#     'upstroke_t': 0.51694,
#     'upstroke_v': -24.875001907348633,
#     'downstroke_index': 51867,
#     'downstroke': -165.53941408591922,
#     'downstroke_t': 0.5173399999999999,
#     'downstroke_v': -19.375,
#     'isi_type': 'direct',
#     'fast_trough_index': 51914,
#     'fast_trough_t': 0.5182800000000001,
#     'fast_trough_v': -68.3125,
#     'fast_trough_i': 190,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0004999999999999449,
#     'upstroke_downstroke_ratio': 2.0828869597874577},
#    {'threshold_index': 52492,
#     'clipped': False,
#     'threshold_t': 0.5298400000000001,
#     'threshold_v': -54.500003814697266,
#     'threshold_i': 190,
#     'peak_index': 52512,
#     'peak_t': 0.53024,
#     'peak_v': 7.375000476837158,
#     'peak_i': 190,
#     'trough_index': 52575,
#     'trough_t': 0.5315000000000001,
#     'trough_v': -66.90625,
#     'trough_i': 190,
#     'upstroke_index': 52504,
#     'upstroke': 318.3086760376781,
#     'upstroke_t': 0.5300799999999999,
#     'upstroke_v': -23.062501907348633,
#     'downstroke_index': 52525,
#     'downstroke': -152.1182920077424,
#     'downstroke_t': 0.5305,
#     'downstroke_v': -18.65625,
#     'isi_type': 'direct',
#     'fast_trough_index': 52574,
#     'fast_trough_t': 0.53148,
#     'fast_trough_v': -66.78125,
#     'fast_trough_i': 190,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000520000000000076,
#     'upstroke_downstroke_ratio': 2.092507559981524},
#    {'threshold_index': 53235,
#     'clipped': False,
#     'threshold_t': 0.5447,
#     'threshold_v': -52.96875,
#     'threshold_i': 190,
#     'peak_index': 53256,
#     'peak_t': 0.54512,
#     'peak_v': 7.093750476837158,
#     'peak_i': 190,
#     'trough_index': 53324,
#     'trough_t': 0.5464800000000001,
#     'trough_v': -66.1875,
#     'trough_i': 190,
#     'upstroke_index': 53247,
#     'upstroke': 298.32539358634415,
#     'upstroke_t': 0.54494,
#     'upstroke_v': -24.71875,
#     'downstroke_index': 53269,
#     'downstroke': -140.82330715963934,
#     'downstroke_t': 0.54538,
#     'downstroke_v': -18.15625,
#     'isi_type': 'direct',
#     'fast_trough_index': 53321,
#     'fast_trough_t': 0.5464199999999999,
#     'fast_trough_v': -66.09375,
#     'fast_trough_i': 190,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005599999999998939,
#     'upstroke_downstroke_ratio': 2.1184376336806103},
#    {'threshold_index': 54106,
#     'clipped': False,
#     'threshold_t': 0.56212,
#     'threshold_v': -50.937503814697266,
#     'threshold_i': 190,
#     'peak_index': 54127,
#     'peak_t': 0.56254,
#     'peak_v': 6.906250476837158,
#     'peak_i': 190,
#     'trough_index': 54195,
#     'trough_t': 0.5639000000000001,
#     'trough_v': -65.375,
#     'trough_i': 190,
#     'upstroke_index': 54117,
#     'upstroke': 280.4029770839063,
#     'upstroke_t': 0.5623400000000001,
#     'upstroke_v': -26.093751907348633,
#     'downstroke_index': 54140,
#     'downstroke': -136.73412746788554,
#     'downstroke_t': 0.5628,
#     'downstroke_v': -18.406251907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 54192,
#     'fast_trough_t': 0.5638399999999999,
#     'fast_trough_v': -65.28125,
#     'fast_trough_i': 190,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005800000000000249,
#     'upstroke_downstroke_ratio': 2.0507168347548346},
#    {'threshold_index': 55073,
#     'clipped': False,
#     'threshold_t': 0.5814600000000001,
#     'threshold_v': -49.968753814697266,
#     'threshold_i': 190,
#     'peak_index': 55095,
#     'peak_t': 0.5819000000000001,
#     'peak_v': 6.593750476837158,
#     'peak_i': 190,
#     'trough_index': 55169,
#     'trough_t': 0.58338,
#     'trough_v': -65.18750762939453,
#     'trough_i': 190,
#     'upstroke_index': 55086,
#     'upstroke': 268.515629206281,
#     'upstroke_t': 0.58172,
#     'upstroke_v': -20.21875,
#     'downstroke_index': 55108,
#     'downstroke': -131.8042263935078,
#     'downstroke_t': 0.58216,
#     'downstroke_v': -17.562501907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 55160,
#     'fast_trough_t': 0.5831999999999999,
#     'fast_trough_v': -64.96875,
#     'fast_trough_i': 190,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005800000000000249,
#     'upstroke_downstroke_ratio': 2.037230797171972},
#    {'threshold_index': 56259,
#     'clipped': False,
#     'threshold_t': 0.60518,
#     'threshold_v': -47.906253814697266,
#     'threshold_i': 190,
#     'peak_index': 56281,
#     'peak_t': 0.60562,
#     'peak_v': 6.437500476837158,
#     'peak_i': 190,
#     'trough_index': 56348,
#     'trough_t': 0.6069599999999999,
#     'trough_v': -64.68750762939453,
#     'trough_i': 190,
#     'upstroke_index': 56271,
#     'upstroke': 259.9934610941251,
#     'upstroke_t': 0.6054200000000001,
#     'upstroke_v': -21.312501907348633,
#     'downstroke_index': 56293,
#     'downstroke': -128.81919767603847,
#     'downstroke_t': 0.6058600000000001,
#     'downstroke_v': -15.656251907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 56348,
#     'fast_trough_t': 0.6069599999999999,
#     'fast_trough_v': -64.68750762939453,
#     'fast_trough_i': 190,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
# ...
#     'trough_t': 1.36238,
#     'trough_v': -59.843753814697266,
#     'trough_i': 270,
#     'upstroke_index': 94029,
#     'upstroke': 199.38056613891186,
#     'upstroke_t': 1.36058,
#     'upstroke_v': -19.78125,
#     'downstroke_index': 94054,
#     'downstroke': -106.07630934897253,
#     'downstroke_t': 1.36108,
#     'downstroke_v': -14.468750953674316,
#     'isi_type': 'direct',
#     'fast_trough_index': 94112,
#     'fast_trough_t': 1.36224,
#     'fast_trough_v': -59.718753814697266,
#     'fast_trough_i': 270,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006799999999997919,
#     'upstroke_downstroke_ratio': 1.8795956171795591},
#    {'threshold_index': 94963,
#     'clipped': False,
#     'threshold_t': 1.37926,
#     'threshold_v': -42.34375,
#     'threshold_i': 270,
#     'peak_index': 94988,
#     'peak_t': 1.3797599999999999,
#     'peak_v': 5.250000476837158,
#     'peak_i': 270,
#     'trough_index': 95067,
#     'trough_t': 1.38134,
#     'trough_v': -60.156253814697266,
#     'trough_i': 270,
#     'upstroke_index': 94977,
#     'upstroke': 196.78554485680948,
#     'upstroke_t': 1.37954,
#     'upstroke_v': -19.000001907348633,
#     'downstroke_index': 95003,
#     'downstroke': -103.8999452599647,
#     'downstroke_t': 1.38006,
#     'downstroke_v': -16.656251907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 95066,
#     'fast_trough_t': 1.3813199999999999,
#     'fast_trough_v': -60.0625,
#     'fast_trough_i': 270,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006999999999999229,
#     'upstroke_downstroke_ratio': 1.8939908424825318},
#    {'threshold_index': 95992,
#     'clipped': False,
#     'threshold_t': 1.39984,
#     'threshold_v': -42.875003814697266,
#     'threshold_i': 270,
#     'peak_index': 96016,
#     'peak_t': 1.40032,
#     'peak_v': 5.000000476837158,
#     'peak_i': 270,
#     'trough_index': 96097,
#     'trough_t': 1.40194,
#     'trough_v': -60.156253814697266,
#     'trough_i': 270,
#     'upstroke_index': 96005,
#     'upstroke': 199.56826274675788,
#     'upstroke_t': 1.4001,
#     'upstroke_v': -21.000001907348633,
#     'downstroke_index': 96031,
#     'downstroke': -105.33509370004695,
#     'downstroke_t': 1.40062,
#     'downstroke_v': -15.875000953674316,
#     'isi_type': 'direct',
#     'fast_trough_index': 96090,
#     'fast_trough_t': 1.4018,
#     'fast_trough_v': -60.031253814697266,
#     'fast_trough_i': 270,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006799999999997919,
#     'upstroke_downstroke_ratio': 1.8946037425575377},
#    {'threshold_index': 97025,
#     'clipped': False,
#     'threshold_t': 1.4204999999999999,
#     'threshold_v': -42.468753814697266,
#     'threshold_i': 270,
#     'peak_index': 97050,
#     'peak_t': 1.421,
#     'peak_v': 5.218750476837158,
#     'peak_i': 270,
#     'trough_index': 97127,
#     'trough_t': 1.42254,
#     'trough_v': -60.281253814697266,
#     'trough_i': 270,
#     'upstroke_index': 97039,
#     'upstroke': 197.36841525146255,
#     'upstroke_t': 1.42078,
#     'upstroke_v': -18.78125,
#     'downstroke_index': 97064,
#     'downstroke': -105.98526544224993,
#     'downstroke_t': 1.4212799999999999,
#     'downstroke_v': -15.062500953674316,
#     'isi_type': 'direct',
#     'fast_trough_index': 97126,
#     'fast_trough_t': 1.42252,
#     'fast_trough_v': -60.187503814697266,
#     'fast_trough_i': 270,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006800000000000139,
#     'upstroke_downstroke_ratio': 1.862225040696871},
#    {'threshold_index': 98048,
#     'clipped': False,
#     'threshold_t': 1.44096,
#     'threshold_v': -42.5,
#     'threshold_i': 270,
#     'peak_index': 98072,
#     'peak_t': 1.44144,
#     'peak_v': 5.437500476837158,
#     'peak_i': 270,
#     'trough_index': 98149,
#     'trough_t': 1.44298,
#     'trough_v': -60.468753814697266,
#     'trough_i': 270,
#     'upstroke_index': 98061,
#     'upstroke': 201.72284559521623,
#     'upstroke_t': 1.44122,
#     'upstroke_v': -19.9375,
#     'downstroke_index': 98087,
#     'downstroke': -105.97611968087118,
#     'downstroke_t': 1.44174,
#     'downstroke_v': -17.03125,
#     'isi_type': 'direct',
#     'fast_trough_index': 98147,
#     'fast_trough_t': 1.44294,
#     'fast_trough_v': -60.343753814697266,
#     'fast_trough_i': 270,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000660000000000105,
#     'upstroke_downstroke_ratio': 1.903474539383682},
#    {'threshold_index': 99044,
#     'clipped': False,
#     'threshold_t': 1.46088,
#     'threshold_v': -42.625003814697266,
#     'threshold_i': 270,
#     'peak_index': 99069,
#     'peak_t': 1.46138,
#     'peak_v': 5.375,
#     'peak_i': 270,
#     'trough_index': 99151,
#     'trough_t': 1.46302,
#     'trough_v': -59.843753814697266,
#     'trough_i': 270,
#     'upstroke_index': 99058,
#     'upstroke': 197.45182152053766,
#     'upstroke_t': 1.46116,
#     'upstroke_v': -18.21875,
#     'downstroke_index': 99083,
#     'downstroke': -105.75877300211788,
#     'downstroke_t': 1.46166,
#     'downstroke_v': -15.218750953674316,
#     'isi_type': 'direct',
#     'fast_trough_index': 99141,
#     'fast_trough_t': 1.46282,
#     'fast_trough_v': -59.625003814697266,
#     'fast_trough_i': 270,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0006800000000000139,
#     'upstroke_downstroke_ratio': 1.8670018185307764},
#    {'threshold_index': 100033,
#     'clipped': False,
#     'threshold_t': 1.4806599999999999,
#     'threshold_v': -42.625003814697266,
#     'threshold_i': 270,
#     'peak_index': 100058,
#     'peak_t': 1.48116,
#     'peak_v': 5.15625,
#     'peak_i': 270,
#     'trough_index': 109571,
#     'trough_t': 1.67142,
#     'trough_v': -84.90625762939453,
#     'trough_i': 0,
#     'upstroke_index': 100047,
#     'upstroke': 197.25287451855115,
#     'upstroke_t': 1.48094,
#     'upstroke_v': -18.718751907348633,
#     'downstroke_index': 100073,
#     'downstroke': -104.09163384585425,
#     'downstroke_t': 1.4814599999999998,
#     'downstroke_v': -16.75,
#     'isi_type': 'detour',
#     'fast_trough_index': 100133,
#     'fast_trough_t': 1.48266,
#     'fast_trough_v': -59.65625,
#     'fast_trough_i': 270,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000700000000000145,
#     'upstroke_downstroke_ratio': 1.8949925871146975}],
#   'sweep_number': 43},
#  44: {'spikes': [], 'sweep_number': 44, 'peak_deflect': (-59.562504, 58859)},
#  45: {'spikes': [{'threshold_index': 55890,
#     'clipped': False,
#     'threshold_t': 0.5977999999999999,
#     'threshold_v': -53.75,
#     'threshold_i': 110,
#     'peak_index': 55910,
#     'peak_t': 0.5982000000000001,
#     'peak_v': 5.937500476837158,
#     'peak_i': 110,
#     'trough_index': 161231,
#     'trough_t': 2.70462,
#     'trough_v': -80.875,
#     'trough_i': 0,
#     'upstroke_index': 55900,
#     'upstroke': 307.57505703963517,
#     'upstroke_t': 0.5980000000000001,
#     'upstroke_v': -30.1875,
#     'downstroke_index': 55922,
#     'downstroke': -147.20072702325405,
#     'downstroke_t': 0.5984400000000001,
#     'downstroke_v': -17.78125,
#     'isi_type': 'detour',
#     'fast_trough_index': 55978,
#     'fast_trough_t': 0.5995600000000001,
#     'fast_trough_v': -67.78125762939453,
#     'fast_trough_i': 110,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000560000000000116,
#     'upstroke_downstroke_ratio': 2.0894941435380683}],
#   'sweep_number': 45},
#  14: {'spikes': [{'threshold_index': 295336,
#     'clipped': False,
#     'threshold_t': 5.38422,
#     'threshold_v': -52.15625,
#     'threshold_i': 122.12500762939453,
#     'peak_index': 295356,
#     'peak_t': 5.38462,
#     'peak_v': 13.71875,
#     'peak_i': 122.12500762939453,
#     'trough_index': 295426,
#     'trough_t': 5.38602,
#     'trough_v': -66.8125,
#     'trough_i': 122.25,
#     'upstroke_index': 295346,
#     'upstroke': 340.96489816277085,
#     'upstroke_t': 5.38442,
#     'upstroke_v': -26.187501907348633,
#     'downstroke_index': 295369,
#     'downstroke': -163.51525525944066,
#     'downstroke_t': 5.38488,
#     'downstroke_v': -17.375001907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 295420,
#     'fast_trough_t': 5.3859,
#     'fast_trough_v': -66.6875,
#     'fast_trough_i': 122.25,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005399999999999849,
#     'upstroke_downstroke_ratio': 2.085217661323285},
#    {'threshold_index': 317414,
#     'clipped': False,
#     'threshold_t': 5.82578,
#     'threshold_v': -50.687503814697266,
#     'threshold_i': 133.25,
#     'peak_index': 317434,
#     'peak_t': 5.82618,
#     'peak_v': 12.625,
#     'peak_i': 133.25,
#     'trough_index': 317508,
#     'trough_t': 5.82766,
#     'trough_v': -66.34375762939453,
#     'trough_i': 133.25,
#     'upstroke_index': 317425,
#     'upstroke': 326.1813005029107,
#     'upstroke_t': 5.826,
#     'upstroke_v': -21.031251907348633,
#     'downstroke_index': 317447,
#     'downstroke': -161.01635472873298,
#     'downstroke_t': 5.82644,
#     'downstroke_v': -16.937501907348633,
#     'isi_type': 'direct',
#     'fast_trough_index': 317501,
#     'fast_trough_t': 5.82752,
#     'fast_trough_v': -66.28125,
#     'fast_trough_i': 133.25,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005399999999999849,
#     'upstroke_downstroke_ratio': 2.025765028977547},
#    {'threshold_index': 323371,
#     'clipped': False,
#     'threshold_t': 5.94492,
#     'threshold_v': -49.78125,
#     'threshold_i': 136.125,
#     'peak_index': 323391,
#     'peak_t': 5.94532,
#     'peak_v': 12.156250953674316,
#     'peak_i': 136.25,
#     'trough_index': 323458,
#     'trough_t': 5.94666,
#     'trough_v': -65.90625762939453,
#     'trough_i': 136.25,
#     'upstroke_index': 323381,
#     'upstroke': 310.59855346348985,
#     'upstroke_t': 5.94512,
#     'upstroke_v': -24.8125,
#     'downstroke_index': 323404,
#     'downstroke': -156.39142426266753,
#     'downstroke_t': 5.94558,
#     'downstroke_v': -16.71875,
#     'isi_type': 'direct',
#     'fast_trough_index': 323453,
#     'fast_trough_t': 5.94656,
#     'fast_trough_v': -65.78125,
#     'fast_trough_i': 136.25,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.000560000000000116,
#     'upstroke_downstroke_ratio': 1.986033153210648},
#    {'threshold_index': 333542,
#     'clipped': False,
#     'threshold_t': 6.14834,
#     'threshold_v': -48.937503814697266,
#     'threshold_i': 141.25,
#     'peak_index': 333562,
#     'peak_t': 6.14874,
#     'peak_v': 11.6875,
#     'peak_i': 141.25,
#     'trough_index': 333634,
#     'trough_t': 6.15018,
#     'trough_v': -65.6875,
#     'trough_i': 141.375,
#     'upstroke_index': 333553,
#     'upstroke': 306.01717154173406,
#     'upstroke_t': 6.14856,
#     'upstroke_v': -21.031251907348633,
#     'downstroke_index': 333575,
#     'downstroke': -155.37007477376844,
#     'downstroke_t': 6.149,
#     'downstroke_v': -15.78125,
#     'isi_type': 'direct',
#     'fast_trough_index': 333627,
#     'fast_trough_t': 6.15004,
#     'fast_trough_v': -65.53125,
#     'fast_trough_i': 141.375,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.0005399999999999849,
#     'upstroke_downstroke_ratio': 1.9696017523794085}],
#   'sweep_number': 14},
#  15: {'spikes': [], 'sweep_number': 15},
#  16: {'spikes': [], 'sweep_number': 16},
#  17: {'spikes': [], 'sweep_number': 17},
#  18: {'spikes': [], 'sweep_number': 18},
#  19: {'spikes': [], 'sweep_number': 19},
#  20: {'spikes': [{'threshold_index': 51145,
#     'clipped': False,
#     'threshold_t': 0.5028999999999999,
#     'threshold_v': -55.218753814697266,
#     'threshold_i': 600,
#     'peak_index': 51163,
#     'peak_t': 0.50326,
#     'peak_v': 10.75,
#     'peak_i': 0,
#     'trough_index': 93062,
#     'trough_t': 1.34124,
#     'trough_v': -81.46875,
#     'trough_i': 0,
#     'upstroke_index': 51155,
#     'upstroke': 372.4523104251405,
#     'upstroke_t': 0.5030999999999999,
#     'upstroke_v': -25.656251907348633,
#     'downstroke_index': 51175,
#     'downstroke': -183.27135976225887,
#     'downstroke_t': 0.5035000000000001,
#     'downstroke_v': -20.031251907348633,
#     'isi_type': 'detour',
#     'fast_trough_index': 51225,
#     'fast_trough_t': 0.5045,
#     'fast_trough_v': -70.53125762939453,
#     'fast_trough_i': 0,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.00048000000000003595,
#     'upstroke_downstroke_ratio': 2.032245032220467}],
#   'sweep_number': 20},
#  21: {'spikes': [], 'sweep_number': 21},
#  22: {'spikes': [{'threshold_index': 51149,
#     'clipped': False,
#     'threshold_t': 0.50298,
#     'threshold_v': -54.781253814697266,
#     'threshold_i': 570,
#     'peak_index': 51167,
#     'peak_t': 0.5033399999999999,
#     'peak_v': 11.312500953674316,
#     'peak_i': 0,
#     'trough_index': 65355,
#     'trough_t': 0.7870999999999999,
#     'trough_v': -80.84375762939453,
#     'trough_i': 0,
#     'upstroke_index': 51159,
#     'upstroke': 371.97801135486594,
#     'upstroke_t': 0.50318,
#     'upstroke_v': -23.156251907348633,
#     'downstroke_index': 51179,
#     'downstroke': -182.97301548117187,
#     'downstroke_t': 0.5035799999999999,
#     'downstroke_v': -20.156251907348633,
#     'isi_type': 'detour',
#     'fast_trough_index': 51229,
#     'fast_trough_t': 0.50458,
#     'fast_trough_v': -70.96875762939453,
#     'fast_trough_i': 0,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.00048000000000003595,
#     'upstroke_downstroke_ratio': 2.0329665026105608}],
#   'sweep_number': 22},
#  23: {'spikes': [{'threshold_index': 51151,
#     'clipped': False,
#     'threshold_t': 0.50302,
#     'threshold_v': -54.875,
#     'threshold_i': 0,
#     'peak_index': 51170,
#     'peak_t': 0.5034000000000001,
#     'peak_v': 11.625,
#     'peak_i': 0,
#     'trough_index': 79602,
#     'trough_t': 1.0720399999999999,
#     'trough_v': -80.90625762939453,
#     'trough_i': 0,
#     'upstroke_index': 51162,
#     'upstroke': 370.23132461115813,
#     'upstroke_t': 0.5032399999999999,
#     'upstroke_v': -23.343751907348633,
#     'downstroke_index': 51182,
#     'downstroke': -185.5297949014292,
#     'downstroke_t': 0.5036400000000001,
#     'downstroke_v': -19.90625,
#     'isi_type': 'detour',
#     'fast_trough_index': 51232,
#     'fast_trough_t': 0.50464,
#     'fast_trough_v': -71.03125,
#     'fast_trough_i': 0,
#     'adp_index': nan,
#     'adp_t': nan,
#     'adp_v': nan,
#     'adp_i': nan,
#     'slow_trough_index': nan,
#     'slow_trough_t': nan,
#     'slow_trough_v': nan,
#     'slow_trough_i': nan,
#     'width': 0.00048000000000003595,
#     'upstroke_downstroke_ratio': 1.995535675592482}],
#   'sweep_number': 23}}
